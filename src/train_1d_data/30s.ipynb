# %%
import pandas as pd
import numpy  as np
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split 

RESEARCH_WORK_PATH = "/content/drive/MyDrive/Colab Notebooks/BachelorResearch/"

# %%
feelings = 'Q1 Q2 Q3 Q4'.split()
csv_path = RESEARCH_WORK_PATH + "note/data.csv"

data = pd.read_csv(csv_path, usecols=range(0, 28))
data = data[data['label'].isin(feelings)].reset_index(drop=True)
data = data.drop(['filename'],axis=1)
genre_list = data.iloc[:, -1]
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(genre_list)
y = to_categorical(y, num_classes=4)
scaler = StandardScaler()
X = scaler.fit_transform(np.array(data.iloc[:, :-1], dtype = float))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (640, 26)
# (640, 4)

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(256, activation='relu', input_shape=(X_train.shape[1],)))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(4, activation='softmax'))

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               6912
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 48,324
# Trainable params: 48,324
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
hist = model.fit(X_train,
                    y_train,
                    epochs=100,
                    validation_data=(X_test,y_test),
                    batch_size=32).history
# Out:
# Epoch 1/100
# 20/20 [==============================] - 0s 11ms/step - loss: 0.1511 - accuracy: 0.9688 - val_loss: 1.8663 - val_accuracy: 0.5000
# Epoch 2/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1350 - accuracy: 0.9703 - val_loss: 1.9455 - val_accuracy: 0.5063
# Epoch 3/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1279 - accuracy: 0.9750 - val_loss: 2.0982 - val_accuracy: 0.5125
# Epoch 4/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1080 - accuracy: 0.9828 - val_loss: 1.9976 - val_accuracy: 0.5125
# Epoch 5/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0851 - accuracy: 0.9844 - val_loss: 2.1267 - val_accuracy: 0.5188
# Epoch 6/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0728 - accuracy: 0.9906 - val_loss: 2.1696 - val_accuracy: 0.4938
# Epoch 7/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0717 - accuracy: 0.9937 - val_loss: 2.2123 - val_accuracy: 0.5125
# Epoch 8/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0545 - accuracy: 0.9969 - val_loss: 2.3087 - val_accuracy: 0.5125
# Epoch 9/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0442 - accuracy: 0.9953 - val_loss: 2.3554 - val_accuracy: 0.5250
# Epoch 10/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0335 - accuracy: 1.0000 - val_loss: 2.4449 - val_accuracy: 0.5000
# Epoch 11/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0301 - accuracy: 1.0000 - val_loss: 2.5001 - val_accuracy: 0.4938
# Epoch 12/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0250 - accuracy: 1.0000 - val_loss: 2.5911 - val_accuracy: 0.5063
# Epoch 13/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0212 - accuracy: 1.0000 - val_loss: 2.6047 - val_accuracy: 0.5063
# Epoch 14/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0174 - accuracy: 1.0000 - val_loss: 2.7181 - val_accuracy: 0.5188
# Epoch 15/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 2.7371 - val_accuracy: 0.5000
# Epoch 16/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 2.7869 - val_accuracy: 0.5125
# Epoch 17/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 2.8383 - val_accuracy: 0.5000
# Epoch 18/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 2.8686 - val_accuracy: 0.5000
# Epoch 19/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 2.9140 - val_accuracy: 0.5063
# Epoch 20/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 2.9370 - val_accuracy: 0.5063
# Epoch 21/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 2.9985 - val_accuracy: 0.5063
# Epoch 22/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 3.0152 - val_accuracy: 0.5063
# Epoch 23/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 3.0557 - val_accuracy: 0.5125
# Epoch 24/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 3.0822 - val_accuracy: 0.5125
# Epoch 25/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 3.1146 - val_accuracy: 0.5125
# Epoch 26/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 3.1508 - val_accuracy: 0.5125
# Epoch 27/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 3.1731 - val_accuracy: 0.5125
# Epoch 28/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 3.2134 - val_accuracy: 0.5000
# Epoch 29/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 3.2364 - val_accuracy: 0.5188
# Epoch 30/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 3.2686 - val_accuracy: 0.5125
# Epoch 31/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 3.2881 - val_accuracy: 0.5188
# Epoch 32/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 3.3240 - val_accuracy: 0.5000
# Epoch 33/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 3.3412 - val_accuracy: 0.5188
# Epoch 34/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 3.3648 - val_accuracy: 0.5125
# Epoch 35/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 3.3907 - val_accuracy: 0.5063
# Epoch 36/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 3.4064 - val_accuracy: 0.5188
# Epoch 37/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 3.4349 - val_accuracy: 0.5125
# Epoch 38/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 3.4517 - val_accuracy: 0.5188
# Epoch 39/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 3.4807 - val_accuracy: 0.5063
# Epoch 40/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 3.4917 - val_accuracy: 0.5188
# Epoch 41/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 3.5216 - val_accuracy: 0.5188
# Epoch 42/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 3.5353 - val_accuracy: 0.5063
# Epoch 43/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 3.5584 - val_accuracy: 0.5125
# Epoch 44/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 3.5778 - val_accuracy: 0.5063
# Epoch 45/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 3.5917 - val_accuracy: 0.5188
# Epoch 46/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 3.6143 - val_accuracy: 0.5063
# Epoch 47/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 3.6335 - val_accuracy: 0.5125
# Epoch 48/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 3.6478 - val_accuracy: 0.5063
# Epoch 49/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 3.6652 - val_accuracy: 0.5125
# Epoch 50/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 3.6818 - val_accuracy: 0.5125
# Epoch 51/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 3.7091 - val_accuracy: 0.5063
# Epoch 52/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 3.7133 - val_accuracy: 0.5063
# Epoch 53/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.7365 - val_accuracy: 0.5063
# Epoch 54/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.7498 - val_accuracy: 0.5125
# Epoch 55/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 3.7690 - val_accuracy: 0.5063
# Epoch 56/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 3.7839 - val_accuracy: 0.5063
# Epoch 57/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 3.7955 - val_accuracy: 0.5063
# Epoch 58/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.8125 - val_accuracy: 0.5063
# Epoch 59/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.8322 - val_accuracy: 0.5063
# Epoch 60/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 3.8374 - val_accuracy: 0.5063
# Epoch 61/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 3.8560 - val_accuracy: 0.5063
# Epoch 62/100
# 20/20 [==============================] - 0s 4ms/step - loss: 9.7219e-04 - accuracy: 1.0000 - val_loss: 3.8691 - val_accuracy: 0.5063
# Epoch 63/100
# 20/20 [==============================] - 0s 3ms/step - loss: 9.5077e-04 - accuracy: 1.0000 - val_loss: 3.8840 - val_accuracy: 0.5063
# Epoch 64/100
# 20/20 [==============================] - 0s 3ms/step - loss: 9.1761e-04 - accuracy: 1.0000 - val_loss: 3.8990 - val_accuracy: 0.5063
# Epoch 65/100
# 20/20 [==============================] - 0s 4ms/step - loss: 8.8372e-04 - accuracy: 1.0000 - val_loss: 3.9123 - val_accuracy: 0.5063
# Epoch 66/100
# 20/20 [==============================] - 0s 4ms/step - loss: 8.6041e-04 - accuracy: 1.0000 - val_loss: 3.9242 - val_accuracy: 0.5063
# Epoch 67/100
# 20/20 [==============================] - 0s 3ms/step - loss: 8.4186e-04 - accuracy: 1.0000 - val_loss: 3.9430 - val_accuracy: 0.5063
# Epoch 68/100
# 20/20 [==============================] - 0s 4ms/step - loss: 8.1731e-04 - accuracy: 1.0000 - val_loss: 3.9503 - val_accuracy: 0.5063
# Epoch 69/100
# 20/20 [==============================] - 0s 3ms/step - loss: 7.9711e-04 - accuracy: 1.0000 - val_loss: 3.9700 - val_accuracy: 0.5063
# Epoch 70/100
# 20/20 [==============================] - 0s 4ms/step - loss: 7.6171e-04 - accuracy: 1.0000 - val_loss: 3.9805 - val_accuracy: 0.5063
# Epoch 71/100
# 20/20 [==============================] - 0s 4ms/step - loss: 7.3450e-04 - accuracy: 1.0000 - val_loss: 3.9926 - val_accuracy: 0.5063
# Epoch 72/100
# 20/20 [==============================] - 0s 4ms/step - loss: 7.1642e-04 - accuracy: 1.0000 - val_loss: 4.0067 - val_accuracy: 0.5063
# Epoch 73/100
# 20/20 [==============================] - 0s 4ms/step - loss: 6.9930e-04 - accuracy: 1.0000 - val_loss: 4.0187 - val_accuracy: 0.5063
# Epoch 74/100
# 20/20 [==============================] - 0s 4ms/step - loss: 6.8067e-04 - accuracy: 1.0000 - val_loss: 4.0337 - val_accuracy: 0.5063
# Epoch 75/100
# 20/20 [==============================] - 0s 4ms/step - loss: 6.5511e-04 - accuracy: 1.0000 - val_loss: 4.0438 - val_accuracy: 0.5063
# Epoch 76/100
# 20/20 [==============================] - 0s 3ms/step - loss: 6.3813e-04 - accuracy: 1.0000 - val_loss: 4.0594 - val_accuracy: 0.5063
# Epoch 77/100
# 20/20 [==============================] - 0s 4ms/step - loss: 6.1860e-04 - accuracy: 1.0000 - val_loss: 4.0656 - val_accuracy: 0.5063
# Epoch 78/100
# 20/20 [==============================] - 0s 4ms/step - loss: 6.0884e-04 - accuracy: 1.0000 - val_loss: 4.0810 - val_accuracy: 0.5063
# Epoch 79/100
# 20/20 [==============================] - 0s 4ms/step - loss: 5.9286e-04 - accuracy: 1.0000 - val_loss: 4.0958 - val_accuracy: 0.5063
# Epoch 80/100
# 20/20 [==============================] - 0s 4ms/step - loss: 5.7406e-04 - accuracy: 1.0000 - val_loss: 4.1018 - val_accuracy: 0.5063
# Epoch 81/100
# 20/20 [==============================] - 0s 4ms/step - loss: 5.5697e-04 - accuracy: 1.0000 - val_loss: 4.1209 - val_accuracy: 0.5063
# Epoch 82/100
# 20/20 [==============================] - 0s 4ms/step - loss: 5.4492e-04 - accuracy: 1.0000 - val_loss: 4.1323 - val_accuracy: 0.5063
# Epoch 83/100
# 20/20 [==============================] - 0s 4ms/step - loss: 5.2804e-04 - accuracy: 1.0000 - val_loss: 4.1410 - val_accuracy: 0.5063
# Epoch 84/100
# 20/20 [==============================] - 0s 3ms/step - loss: 5.1777e-04 - accuracy: 1.0000 - val_loss: 4.1503 - val_accuracy: 0.5063
# Epoch 85/100
# 20/20 [==============================] - 0s 3ms/step - loss: 5.0276e-04 - accuracy: 1.0000 - val_loss: 4.1631 - val_accuracy: 0.5063
# Epoch 86/100
# 20/20 [==============================] - 0s 4ms/step - loss: 4.9138e-04 - accuracy: 1.0000 - val_loss: 4.1753 - val_accuracy: 0.5063
# Epoch 87/100
# 20/20 [==============================] - 0s 3ms/step - loss: 4.7929e-04 - accuracy: 1.0000 - val_loss: 4.1864 - val_accuracy: 0.5063
# Epoch 88/100
# 20/20 [==============================] - 0s 3ms/step - loss: 4.6244e-04 - accuracy: 1.0000 - val_loss: 4.1995 - val_accuracy: 0.5063
# Epoch 89/100
# 20/20 [==============================] - 0s 4ms/step - loss: 4.5334e-04 - accuracy: 1.0000 - val_loss: 4.2107 - val_accuracy: 0.5063
# Epoch 90/100
# 20/20 [==============================] - 0s 4ms/step - loss: 4.4177e-04 - accuracy: 1.0000 - val_loss: 4.2213 - val_accuracy: 0.5063
# Epoch 91/100
# 20/20 [==============================] - 0s 3ms/step - loss: 4.3156e-04 - accuracy: 1.0000 - val_loss: 4.2307 - val_accuracy: 0.5063
# Epoch 92/100
# 20/20 [==============================] - 0s 5ms/step - loss: 4.2239e-04 - accuracy: 1.0000 - val_loss: 4.2463 - val_accuracy: 0.5063
# Epoch 93/100
# 20/20 [==============================] - 0s 4ms/step - loss: 4.1095e-04 - accuracy: 1.0000 - val_loss: 4.2506 - val_accuracy: 0.5063
# Epoch 94/100
# 20/20 [==============================] - 0s 4ms/step - loss: 4.0127e-04 - accuracy: 1.0000 - val_loss: 4.2655 - val_accuracy: 0.5063
# Epoch 95/100
# 20/20 [==============================] - 0s 4ms/step - loss: 3.9244e-04 - accuracy: 1.0000 - val_loss: 4.2750 - val_accuracy: 0.5063
# Epoch 96/100
# 20/20 [==============================] - 0s 3ms/step - loss: 3.8250e-04 - accuracy: 1.0000 - val_loss: 4.2870 - val_accuracy: 0.5063
# Epoch 97/100
# 20/20 [==============================] - 0s 4ms/step - loss: 3.7355e-04 - accuracy: 1.0000 - val_loss: 4.2968 - val_accuracy: 0.5063
# Epoch 98/100
# 20/20 [==============================] - 0s 4ms/step - loss: 3.6690e-04 - accuracy: 1.0000 - val_loss: 4.2995 - val_accuracy: 0.5063
# Epoch 99/100
# 20/20 [==============================] - 0s 4ms/step - loss: 3.5841e-04 - accuracy: 1.0000 - val_loss: 4.3168 - val_accuracy: 0.5063
# Epoch 100/100
# 20/20 [==============================] - 0s 4ms/step - loss: 3.4873e-04 - accuracy: 1.0000 - val_loss: 4.3235 - val_accuracy: 0.5063

# %%
from matplotlib import pyplot as plt

def plot_history(history):
    # 分類精度の履歴をプロット
    plt.plot(history['accuracy'])
    plt.plot(history['val_accuracy'])
    plt.title('model accuracy')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.legend(['training', 'validation'], loc='lower right')
    plt.show()

    # 損失関数の履歴をプロット
    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    plt.title('model loss')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['training', 'validation'], loc='upper right')
    plt.show()

plot_history(hist)
