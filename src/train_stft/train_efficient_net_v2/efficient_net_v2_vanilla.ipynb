# %%
# !nvidia-smi
# Out:
# Tue Jun 28 15:58:26 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Initializing
from google.colab import drive
import re
import math
from keras import layers
import copy

drive.mount('/content/drive')
# Define constant value
RESEARCH_WORK_PATH = "/content/drive/My Drive/Colab Notebooks/BachelorResearch/"
# Out:
# Mounted at /content/drive

# %%
"""EfficientNet V1 and V2 model configs."""

#################### EfficientNet V1 configs ####################
v1_b0_block_str = [
        'r1_k3_s1_e1_i32_o16_se0.25',
        'r2_k3_s2_e6_i16_o24_se0.25',
        'r2_k5_s2_e6_i24_o40_se0.25',
        'r3_k3_s2_e6_i40_o80_se0.25',
        'r3_k5_s1_e6_i80_o112_se0.25',
        'r4_k5_s2_e6_i112_o192_se0.25',
        'r1_k3_s1_e6_i192_o320_se0.25',
]

#################### EfficientNet V2 configs ####################
v2_base_block = [    # The baseline config for v2 models.
        'r1_k3_s1_e1_i32_o16_c1',
        'r2_k3_s2_e4_i16_o32_c1',
        'r2_k3_s2_e4_i32_o48_c1',
        'r3_k3_s2_e4_i48_o96_se0.25',
        'r5_k3_s1_e6_i96_o112_se0.25',
        'r8_k3_s2_e6_i112_o192_se0.25',
]

v2_s_block = [    # about base * (width1.4, depth1.8)
        'r2_k3_s1_e1_i24_o24_c1',
        'r4_k3_s2_e4_i24_o48_c1',
        'r4_k3_s2_e4_i48_o64_c1',
        'r6_k3_s2_e4_i64_o128_se0.25',
        'r9_k3_s1_e6_i128_o160_se0.25',
        'r15_k3_s2_e6_i160_o256_se0.25',
]


v2_m_block = [    # about base * (width1.6, depth2.2)
        'r3_k3_s1_e1_i24_o24_c1',
        'r5_k3_s2_e4_i24_o48_c1',
        'r5_k3_s2_e4_i48_o80_c1',
        'r7_k3_s2_e4_i80_o160_se0.25',
        'r14_k3_s1_e6_i160_o176_se0.25',
        'r18_k3_s2_e6_i176_o304_se0.25',
        'r5_k3_s1_e6_i304_o512_se0.25',
]


v2_l_block = [    # about base * (width2.0, depth3.1)
        'r4_k3_s1_e1_i32_o32_c1',
        'r7_k3_s2_e4_i32_o64_c1',
        'r7_k3_s2_e4_i64_o96_c1',
        'r10_k3_s2_e4_i96_o192_se0.25',
        'r19_k3_s1_e6_i192_o224_se0.25',
        'r25_k3_s2_e6_i224_o384_se0.25',
        'r7_k3_s1_e6_i384_o640_se0.25',
]

v2_xl_block = [    # only for 21k pretraining.
        'r4_k3_s1_e1_i32_o32_c1',
        'r8_k3_s2_e4_i32_o64_c1',
        'r8_k3_s2_e4_i64_o96_c1',
        'r16_k3_s2_e4_i96_o192_se0.25',
        'r24_k3_s1_e6_i192_o256_se0.25',
        'r32_k3_s2_e6_i256_o512_se0.25',
        'r8_k3_s1_e6_i512_o640_se0.25',
]
efficientnet_params = {
        # (block, width, depth, train_size, eval_size, dropout, randaug, mixup, aug)
        'efficientnetv2-s':    # 83.9% @ 22M
                (v2_s_block, 1.0, 1.0, 300, 384, 0.2, 10, 0, 'randaug'),
        'efficientnetv2-m':    # 85.2% @ 54M
                (v2_m_block, 1.0, 1.0, 384, 480, 0.3, 15, 0.2, 'randaug'),
        'efficientnetv2-l':    # 85.7% @ 120M
                (v2_l_block, 1.0, 1.0, 384, 480, 0.4, 20, 0.5, 'randaug'),

        'efficientnetv2-xl':
                (v2_xl_block, 1.0, 1.0, 384, 512, 0.4, 20, 0.5, 'randaug'),

        # For fair comparison to EfficientNetV1, using the same scaling and autoaug.
        'efficientnetv2-b0':    # 78.7% @ 7M params
                (v2_base_block, 1.0, 1.0, 192, 224, 0.2, 0, 0, 'effnetv1_autoaug'),
        'efficientnetv2-b1':    # 79.8% @ 8M params
                (v2_base_block, 1.0, 1.1, 192, 240, 0.2, 0, 0, 'effnetv1_autoaug'),
        'efficientnetv2-b2':    # 80.5% @ 10M params
                (v2_base_block, 1.1, 1.2, 208, 260, 0.3, 0, 0, 'effnetv1_autoaug'),
        'efficientnetv2-b3':    # 82.1% @ 14M params
                (v2_base_block, 1.2, 1.4, 240, 300, 0.3, 0, 0, 'effnetv1_autoaug'),

        'efficientnet-b0': (v1_b0_block_str, 1.0, 1.0, 224, 224, 0.2),
        'efficientnet-b1': (v1_b0_block_str, 1.0, 1.1, 240, 240, 0.2),
        'efficientnet-b2': (v1_b0_block_str, 1.1, 1.2, 260, 260, 0.3),
        'efficientnet-b3': (v1_b0_block_str, 1.2, 1.4, 300, 300, 0.3),
        'efficientnet-b4': (v1_b0_block_str, 1.4, 1.8, 380, 380, 0.4),
        'efficientnet-b5': (v1_b0_block_str, 1.6, 2.2, 456, 456, 0.4),
        'efficientnet-b6': (v1_b0_block_str, 1.8, 2.6, 528, 528, 0.5),
        'efficientnet-b7': (v1_b0_block_str, 2.0, 3.1, 600, 600, 0.5),
        'efficientnet-b8': (v1_b0_block_str, 2.2, 3.6, 672, 672, 0.5),
        'efficientnet-l2': (v1_b0_block_str, 4.3, 5.3, 800, 800, 0.5),
}



class Struct:
        def __init__(self, **entries):
                self.__dict__.update(entries)

def make_config(model_name):
    def round_filters(filters, multiplier, divisor, min_depth=None, skip=False):
        """Round number of filters based on depth multiplier."""
        if skip or not multiplier:
            return filters

        filters = filters*multiplier
        min_depth = min_depth or divisor
        new_filters = max(min_depth, int(filters + divisor / 2) // divisor * divisor)
        return int(new_filters)


    def round_repeats(repeats, multiplier, skip=False):
        """Round number of filters based on depth multiplier."""
        if skip or not multiplier:
            return repeats
        return int(math.ceil(multiplier * repeats))    

    cfg = efficientnet_params[model_name]
    width_coefficient = cfg[1]
    depth_coefficient = cfg[2] 

    block_args_list = []
    for block_string in cfg[0]:
        ops = block_string.split('_')
        options = {}
        for op in ops:
            splits = re.split(r'(\d.*)', op)
            if len(splits) >= 2:
                key, value = splits[:2]
                options[key] = value

        input_filters = round_filters(int(options['i']), width_coefficient, 8)
        output_filters = round_filters(int(options['o']), width_coefficient, 8)

        block0_args =    Struct(
                kernel_size=int(options['k']),
                input_filters=input_filters,
                output_filters=output_filters,
                expand_ratio=int(options['e']),
                se_ratio=float(options['se']) if 'se' in options else 0.0,
                strides=int(options['s']),
                conv_type=int(options['c']) if 'c' in options else 0,
        )

        block_args_list.append(block0_args)
        repeats = round_repeats(int(options['r']), depth_coefficient)
        for _ in range(repeats - 1):
            block_args = copy.deepcopy(block0_args)
            block_args.input_filters=int(output_filters)
            block_args.strides=int(1)
            block_args_list.append(block_args)

    mconfig = Struct(
        name=model_name,
        block_args_list = block_args_list,
        train_size = cfg[3],
        eval_size = cfg[4],
        dropout_rate = cfg[5],
        num_classes = 4,  # changed 1000 to 4
        feature_size = round_filters( 1280, width_coefficient, 8),
        depth_divisor = 8,
        bn_momentum = 0.9,
        bn_epsilon = 1e-3,
        min_depth = 8,
        survival_prob = 0.8,
        weight_decay = 0.0,
        stem_stride=2,

    )
    return mconfig

# %%
def conv_kernel_initializer(shape, dtype=None, partition_info=None):
    del partition_info
    kernel_height, kernel_width, _, out_filters = shape
    fan_out = int(kernel_height * kernel_width * out_filters)
    return tf.random.normal(
            shape, mean=0.0, stddev=np.sqrt(2.0 / fan_out), dtype=dtype)

def dense_kernel_initializer(shape, dtype=None, partition_info=None):
    del partition_info
    init_range = 1.0 / np.sqrt(shape[1])
    return tf.random.uniform(shape, -init_range, init_range, dtype=dtype)

def create_efficientnet(config, input_shape=(None,None,3) , name=None, verbose=0):
    mconfig = config
    BN_KWARGS = {'momentum':mconfig.bn_momentum, 'epsilon':mconfig.bn_epsilon}
    CONV_KWARGS = {'use_bias':False, 'padding':'same', 
                    'kernel_initializer': conv_kernel_initializer, 
                    'kernel_regularizer': tf.keras.regularizers.l2(mconfig.weight_decay)}

    def activation(fn='silu', name=None):
        if fn=='sigmoid':
            return layers.Lambda( lambda y: tf.sigmoid(y), name=name)
        return layers.Lambda( lambda y: tf.nn.silu(y), name=name)

    def conv_bn_act(x, filters, kernel, stride, prefix):
        x = layers.Conv2D( filters, kernel, stride, name=prefix+'_conv2d',    **CONV_KWARGS)(x)
        x = layers.BatchNormalization(name=prefix+'_bnorm', **BN_KWARGS)(x)
        x = activation(name=prefix+'_act')(x)
        return x

    def se(inputs, se_filters, filters, prefix):
        SE_CONV_KWARGS = {'use_bias':True, 'padding':'same', 
                        'kernel_initializer': conv_kernel_initializer,
                        'kernel_regularizer': tf.keras.regularizers.l2(mconfig.weight_decay)}
        x = layers.Lambda(lambda y:tf.reduce_mean(y, [1, 2], keepdims=True), name=prefix+'_se_mean')(inputs)
        x = layers.Conv2D(se_filters, 1, 1, name=prefix+'_se_conv2d_s', **SE_CONV_KWARGS)(x)
        x = activation(name=prefix+'_se_act_s')(x)
        x = layers.Conv2D(filters, 1, 1, name=prefix+'_se_conv2d_e', **SE_CONV_KWARGS)(x)
        x = activation('sigmoid', name=prefix+'_se_act_e')(x)
        x = layers.Multiply(name=prefix+'_se_mult')( [x ,inputs ])
        return x

    def mb_conv(inputs, block_args, prefix):
        filters = block_args.input_filters * block_args.expand_ratio
        se_filters = int(block_args.input_filters*block_args.se_ratio)
        x = inputs
        if block_args.expand_ratio != 1:
            x = layers.Conv2D( filters, 1, 1, name=prefix+'_conv2d_expand', **CONV_KWARGS)(x)
            x = layers.BatchNormalization(name=prefix+'_bnorm_expand', **BN_KWARGS)(x)
            x = activation(name=prefix+'_act_expand')(x)

        x = layers.DepthwiseConv2D( block_args.kernel_size, block_args.strides, name=prefix+'_dwconv2d', **CONV_KWARGS)(x)
        x = layers.BatchNormalization(name=prefix+'_bnorm', **BN_KWARGS)(x)
        x = activation(name=prefix+'_act')(x)
        if se_filters!=0:
            x = se(x, se_filters, filters, prefix=prefix)
        x = layers.Conv2D( block_args.output_filters, 1, 1, name=prefix+'_conv2d_proj', **CONV_KWARGS)(x)
        x = layers.BatchNormalization(name=prefix+'_bnorm_proj', **BN_KWARGS)(x)

        return x

    def fused_mb_conv(inputs, block_args, prefix):
        filters = block_args.input_filters * block_args.expand_ratio
        se_filters = int(block_args.input_filters*block_args.se_ratio)
        x = inputs
        if block_args.expand_ratio != 1:
            x = layers.Conv2D( filters, block_args.kernel_size, block_args.strides, 
                name=prefix+'_conv2d_expand', **CONV_KWARGS)(x)
            x = layers.BatchNormalization(name=prefix+'_bnorm_expand', **BN_KWARGS)(x)
            x = activation(name=prefix+'_act_expand')(x)
            if se_filters!=0:
                x = se(x, se_filters, filters, prefix=prefix)
            x = layers.Conv2D( block_args.output_filters, 1, 1, 
                name = prefix+'_conv2d', **CONV_KWARGS )(x)
            x = layers.BatchNormalization(name=prefix+'_bnorm', **BN_KWARGS)(x)
        else:
            if se_filters!=0:
                x = se(x, se_filters, filters, prefix=prefix)
            x = layers.Conv2D( block_args.output_filters, block_args.kernel_size, block_args.strides,
                name = prefix+'_conv2d', **CONV_KWARGS )(x)
            x = layers.BatchNormalization(name=prefix+'_bnorm', **BN_KWARGS)(x)
            x = activation(name=prefix+'_act')(x) # add act if no expansion.

        return x

    # Input
    x = input = tf.keras.Input(shape=input_shape, name='input')


    # Stem
    stem_filters = mconfig.block_args_list[0].input_filters
    x = conv_bn_act(x, stem_filters , 3, mconfig.stem_stride, prefix='stem')
    if verbose!=0:
        print('stem', 3, stem_filters, mconfig.stem_stride )

    # Blocks
    for i, block_args in enumerate(mconfig.block_args_list):
        shortcut = x
        if block_args.conv_type==0:
            prefix = f'block_{i}'
            x = mb_conv(x, block_args, prefix)
        else:
            prefix = f'block_{i}_fused'
            x = fused_mb_conv(x, block_args, prefix)

        survival_prob = mconfig.survival_prob
        if block_args.strides == 1 and block_args.input_filters==block_args.output_filters:
            if survival_prob:
                # StochasticDepth
                drop_rate = 1.0 - survival_prob
                drop_rate = drop_rate * float(i+1) / len(mconfig.block_args_list)
                survival_prob = 1.0 - drop_rate
                x = layers.Dropout(rate=drop_rate, noise_shape=(None,1,1,1), name=prefix+'_stochdepth')(x)
            x = layers.Add(name=prefix+'_add')([shortcut,x])
        else:
            survival_prob = None

        if verbose!=0:
            print(i, block_args.kernel_size,block_args.input_filters, block_args.output_filters, 
                block_args.strides, block_args.expand_ratio, survival_prob    )

    # Head
    x = conv_bn_act( x,mconfig.feature_size , 1, 1, prefix='head')
    x = layers.GlobalAveragePooling2D(name='head_gap')(x)
    if mconfig.dropout_rate > 0:
        x = layers.Dropout(mconfig.dropout_rate,name='head_dropout')(x)
    output = layers.Dense(mconfig.num_classes,
            kernel_initializer = dense_kernel_initializer,
            kernel_regularizer = tf.keras.regularizers.l2(mconfig.weight_decay),
            use_bias = True, name='head_fc')(x)
    if verbose!=0:
        print('head', mconfig.feature_size, mconfig.num_classes, mconfig.dropout_rate    )

    model = tf.keras.Model(inputs=[input], outputs=[output], name=name)
    if verbose!=0:
        print('params', model.count_params())
    return model

# %%
import os
import shutil
import tensorflow as tf
data_dir = RESEARCH_WORK_PATH + "MER_audio_taffc_dataset_wav/2s/stft_img/"
if os.path.exists("/content/data/"):
  os.rmdir("/content/data/")
shutil.copytree(data_dir, "/content/data/")
data_dir = "/content/data/"

# %%
# data_dir = tf.keras.utils.get_file(
#     'flower_photos',
#     'https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz',
#     untar=True)

# get size of img
import cv2
sample = data_dir + "/Q1/Q1.MT0000040632_1.jpg"
i = cv2.imread(sample)
(img_row, img_col, c) = i.shape
    
datagen_kwargs = dict(rescale=1./255, validation_split=.20)
batch_size = 32
dataflow_kwargs = dict(target_size=(img_row, img_col),
                       batch_size=batch_size,
                       interpolation="bilinear")


valid_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    **datagen_kwargs)
valid_generator = valid_datagen.flow_from_directory(
    data_dir, subset="validation", shuffle=False, **dataflow_kwargs)

do_data_augmentation = False #@param {type:"boolean"}
if do_data_augmentation:
  train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
      rotation_range=40,
      horizontal_flip=True,
      width_shift_range=0.2, height_shift_range=0.2,
      shear_range=0.2, zoom_range=0.2,
      **datagen_kwargs)
else:
  train_datagen = valid_datagen
train_generator = train_datagen.flow_from_directory(
    data_dir, subset="training", shuffle=True, **dataflow_kwargs)
# Out:
# Found 2240 images belonging to 4 classes.
# Found 8960 images belonging to 4 classes.

# %%
# whether to finetune the whole model or just the top layer.
import numpy as np
num_epochs = 200 #@param {type:"integer"}

tf.keras.backend.clear_session()
config = make_config("efficientnetv2-b0")
model = create_efficientnet(config, input_shape=(img_row,img_col,3))
model.summary()

model.compile(
  optimizer=tf.keras.optimizers.SGD(learning_rate=0.00005, momentum=0.9), 
  loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True, label_smoothing=0.1),
  metrics=['accuracy'])

steps_per_epoch = train_generator.samples // train_generator.batch_size
validation_steps = valid_generator.samples // valid_generator.batch_size

import time
st = time.time()
hist = model.fit(
    train_generator,
    epochs=num_epochs, steps_per_epoch=steps_per_epoch,
    validation_data=valid_generator,
    validation_steps=validation_steps).history
et = time.time()
print("[TIME ]", et-st, "s")
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 257, 173, 3  0           []
#                                 )]
#
#  stem_conv2d (Conv2D)           (None, 129, 87, 32)  864         ['input[0][0]']
#
#  stem_bnorm (BatchNormalization  (None, 129, 87, 32)  128        ['stem_conv2d[0][0]']
#  )
#
#  stem_act (Lambda)              (None, 129, 87, 32)  0           ['stem_bnorm[0][0]']
#
#  block_0_fused_conv2d (Conv2D)  (None, 129, 87, 16)  4608        ['stem_act[0][0]']
#
#  block_0_fused_bnorm (BatchNorm  (None, 129, 87, 16)  64         ['block_0_fused_conv2d[0][0]']
#  alization)
#
#  block_0_fused_act (Lambda)     (None, 129, 87, 16)  0           ['block_0_fused_bnorm[0][0]']
#
#  block_1_fused_conv2d_expand (C  (None, 65, 44, 64)  9216        ['block_0_fused_act[0][0]']
#  onv2D)
#
#  block_1_fused_bnorm_expand (Ba  (None, 65, 44, 64)  256         ['block_1_fused_conv2d_expand[0][
#  tchNormalization)                                               0]']
#
#  block_1_fused_act_expand (Lamb  (None, 65, 44, 64)  0           ['block_1_fused_bnorm_expand[0][0
#  da)                                                             ]']
#
#  block_1_fused_conv2d (Conv2D)  (None, 65, 44, 32)   2048        ['block_1_fused_act_expand[0][0]'
#                                                                  ]
#
#  block_1_fused_bnorm (BatchNorm  (None, 65, 44, 32)  128         ['block_1_fused_conv2d[0][0]']
#  alization)
#
#  block_2_fused_conv2d_expand (C  (None, 65, 44, 128)  36864      ['block_1_fused_bnorm[0][0]']
#  onv2D)
#
#  block_2_fused_bnorm_expand (Ba  (None, 65, 44, 128)  512        ['block_2_fused_conv2d_expand[0][
#  tchNormalization)                                               0]']
#
#  block_2_fused_act_expand (Lamb  (None, 65, 44, 128)  0          ['block_2_fused_bnorm_expand[0][0
#  da)                                                             ]']
#
#  block_2_fused_conv2d (Conv2D)  (None, 65, 44, 32)   4096        ['block_2_fused_act_expand[0][0]'
#                                                                  ]
#
#  block_2_fused_bnorm (BatchNorm  (None, 65, 44, 32)  128         ['block_2_fused_conv2d[0][0]']
#  alization)
#
#  block_2_fused_stochdepth (Drop  (None, 65, 44, 32)  0           ['block_2_fused_bnorm[0][0]']
#  out)
#
#  block_2_fused_add (Add)        (None, 65, 44, 32)   0           ['block_1_fused_bnorm[0][0]',
#                                                                   'block_2_fused_stochdepth[0][0]'
#                                                                  ]
#
#  block_3_fused_conv2d_expand (C  (None, 33, 22, 128)  36864      ['block_2_fused_add[0][0]']
#  onv2D)
#
#  block_3_fused_bnorm_expand (Ba  (None, 33, 22, 128)  512        ['block_3_fused_conv2d_expand[0][
#  tchNormalization)                                               0]']
#
#  block_3_fused_act_expand (Lamb  (None, 33, 22, 128)  0          ['block_3_fused_bnorm_expand[0][0
#  da)                                                             ]']
#
#  block_3_fused_conv2d (Conv2D)  (None, 33, 22, 48)   6144        ['block_3_fused_act_expand[0][0]'
#                                                                  ]
#
#  block_3_fused_bnorm (BatchNorm  (None, 33, 22, 48)  192         ['block_3_fused_conv2d[0][0]']
#  alization)
#
#  block_4_fused_conv2d_expand (C  (None, 33, 22, 192)  82944      ['block_3_fused_bnorm[0][0]']
#  onv2D)
#
#  block_4_fused_bnorm_expand (Ba  (None, 33, 22, 192)  768        ['block_4_fused_conv2d_expand[0][
#  tchNormalization)                                               0]']
#
#  block_4_fused_act_expand (Lamb  (None, 33, 22, 192)  0          ['block_4_fused_bnorm_expand[0][0
#  da)                                                             ]']
#
#  block_4_fused_conv2d (Conv2D)  (None, 33, 22, 48)   9216        ['block_4_fused_act_expand[0][0]'
#                                                                  ]
#
#  block_4_fused_bnorm (BatchNorm  (None, 33, 22, 48)  192         ['block_4_fused_conv2d[0][0]']
#  alization)
#
#  block_4_fused_stochdepth (Drop  (None, 33, 22, 48)  0           ['block_4_fused_bnorm[0][0]']
#  out)
#
#  block_4_fused_add (Add)        (None, 33, 22, 48)   0           ['block_3_fused_bnorm[0][0]',
#                                                                   'block_4_fused_stochdepth[0][0]'
#                                                                  ]
#
#  block_5_conv2d_expand (Conv2D)  (None, 33, 22, 192)  9216       ['block_4_fused_add[0][0]']
#
#  block_5_bnorm_expand (BatchNor  (None, 33, 22, 192)  768        ['block_5_conv2d_expand[0][0]']
#  malization)
#
#  block_5_act_expand (Lambda)    (None, 33, 22, 192)  0           ['block_5_bnorm_expand[0][0]']
#
#  block_5_dwconv2d (DepthwiseCon  (None, 17, 11, 192)  1728       ['block_5_act_expand[0][0]']
#  v2D)
#
#  block_5_bnorm (BatchNormalizat  (None, 17, 11, 192)  768        ['block_5_dwconv2d[0][0]']
#  ion)
#
#  block_5_act (Lambda)           (None, 17, 11, 192)  0           ['block_5_bnorm[0][0]']
#
#  block_5_se_mean (Lambda)       (None, 1, 1, 192)    0           ['block_5_act[0][0]']
#
#  block_5_se_conv2d_s (Conv2D)   (None, 1, 1, 12)     2316        ['block_5_se_mean[0][0]']
#
#  block_5_se_act_s (Lambda)      (None, 1, 1, 12)     0           ['block_5_se_conv2d_s[0][0]']
#
#  block_5_se_conv2d_e (Conv2D)   (None, 1, 1, 192)    2496        ['block_5_se_act_s[0][0]']
#
#  block_5_se_act_e (Lambda)      (None, 1, 1, 192)    0           ['block_5_se_conv2d_e[0][0]']
#
#  block_5_se_mult (Multiply)     (None, 17, 11, 192)  0           ['block_5_se_act_e[0][0]',
#                                                                   'block_5_act[0][0]']
#
#  block_5_conv2d_proj (Conv2D)   (None, 17, 11, 96)   18432       ['block_5_se_mult[0][0]']
#
#  block_5_bnorm_proj (BatchNorma  (None, 17, 11, 96)  384         ['block_5_conv2d_proj[0][0]']
#  lization)
#
#  block_6_conv2d_expand (Conv2D)  (None, 17, 11, 384)  36864      ['block_5_bnorm_proj[0][0]']
#
#  block_6_bnorm_expand (BatchNor  (None, 17, 11, 384)  1536       ['block_6_conv2d_expand[0][0]']
#  malization)
#
#  block_6_act_expand (Lambda)    (None, 17, 11, 384)  0           ['block_6_bnorm_expand[0][0]']
#
#  block_6_dwconv2d (DepthwiseCon  (None, 17, 11, 384)  3456       ['block_6_act_expand[0][0]']
#  v2D)
#
#  block_6_bnorm (BatchNormalizat  (None, 17, 11, 384)  1536       ['block_6_dwconv2d[0][0]']
#  ion)
#
#  block_6_act (Lambda)           (None, 17, 11, 384)  0           ['block_6_bnorm[0][0]']
#
#  block_6_se_mean (Lambda)       (None, 1, 1, 384)    0           ['block_6_act[0][0]']
#
#  block_6_se_conv2d_s (Conv2D)   (None, 1, 1, 24)     9240        ['block_6_se_mean[0][0]']
#
#  block_6_se_act_s (Lambda)      (None, 1, 1, 24)     0           ['block_6_se_conv2d_s[0][0]']
#
#  block_6_se_conv2d_e (Conv2D)   (None, 1, 1, 384)    9600        ['block_6_se_act_s[0][0]']
#
#  block_6_se_act_e (Lambda)      (None, 1, 1, 384)    0           ['block_6_se_conv2d_e[0][0]']
#
#  block_6_se_mult (Multiply)     (None, 17, 11, 384)  0           ['block_6_se_act_e[0][0]',
#                                                                   'block_6_act[0][0]']
#
#  block_6_conv2d_proj (Conv2D)   (None, 17, 11, 96)   36864       ['block_6_se_mult[0][0]']
#
#  block_6_bnorm_proj (BatchNorma  (None, 17, 11, 96)  384         ['block_6_conv2d_proj[0][0]']
#  lization)
#
#  block_6_stochdepth (Dropout)   (None, 17, 11, 96)   0           ['block_6_bnorm_proj[0][0]']
#
#  block_6_add (Add)              (None, 17, 11, 96)   0           ['block_5_bnorm_proj[0][0]',
#                                                                   'block_6_stochdepth[0][0]']
#
#  block_7_conv2d_expand (Conv2D)  (None, 17, 11, 384)  36864      ['block_6_add[0][0]']
#
#  block_7_bnorm_expand (BatchNor  (None, 17, 11, 384)  1536       ['block_7_conv2d_expand[0][0]']
#  malization)
#
#  block_7_act_expand (Lambda)    (None, 17, 11, 384)  0           ['block_7_bnorm_expand[0][0]']
#
#  block_7_dwconv2d (DepthwiseCon  (None, 17, 11, 384)  3456       ['block_7_act_expand[0][0]']
#  v2D)
#
#  block_7_bnorm (BatchNormalizat  (None, 17, 11, 384)  1536       ['block_7_dwconv2d[0][0]']
#  ion)
#
#  block_7_act (Lambda)           (None, 17, 11, 384)  0           ['block_7_bnorm[0][0]']
#
#  block_7_se_mean (Lambda)       (None, 1, 1, 384)    0           ['block_7_act[0][0]']
#
#  block_7_se_conv2d_s (Conv2D)   (None, 1, 1, 24)     9240        ['block_7_se_mean[0][0]']
#
#  block_7_se_act_s (Lambda)      (None, 1, 1, 24)     0           ['block_7_se_conv2d_s[0][0]']
#
#  block_7_se_conv2d_e (Conv2D)   (None, 1, 1, 384)    9600        ['block_7_se_act_s[0][0]']
#
#  block_7_se_act_e (Lambda)      (None, 1, 1, 384)    0           ['block_7_se_conv2d_e[0][0]']
#
#  block_7_se_mult (Multiply)     (None, 17, 11, 384)  0           ['block_7_se_act_e[0][0]',
#                                                                   'block_7_act[0][0]']
#
#  block_7_conv2d_proj (Conv2D)   (None, 17, 11, 96)   36864       ['block_7_se_mult[0][0]']
#
#  block_7_bnorm_proj (BatchNorma  (None, 17, 11, 96)  384         ['block_7_conv2d_proj[0][0]']
#  lization)
#
#  block_7_stochdepth (Dropout)   (None, 17, 11, 96)   0           ['block_7_bnorm_proj[0][0]']
#
#  block_7_add (Add)              (None, 17, 11, 96)   0           ['block_6_add[0][0]',
#                                                                   'block_7_stochdepth[0][0]']
#
#  block_8_conv2d_expand (Conv2D)  (None, 17, 11, 576)  55296      ['block_7_add[0][0]']
#
#  block_8_bnorm_expand (BatchNor  (None, 17, 11, 576)  2304       ['block_8_conv2d_expand[0][0]']
#  malization)
#
#  block_8_act_expand (Lambda)    (None, 17, 11, 576)  0           ['block_8_bnorm_expand[0][0]']
#
#  block_8_dwconv2d (DepthwiseCon  (None, 17, 11, 576)  5184       ['block_8_act_expand[0][0]']
#  v2D)
#
#  block_8_bnorm (BatchNormalizat  (None, 17, 11, 576)  2304       ['block_8_dwconv2d[0][0]']
#  ion)
#
#  block_8_act (Lambda)           (None, 17, 11, 576)  0           ['block_8_bnorm[0][0]']
#
#  block_8_se_mean (Lambda)       (None, 1, 1, 576)    0           ['block_8_act[0][0]']
#
#  block_8_se_conv2d_s (Conv2D)   (None, 1, 1, 24)     13848       ['block_8_se_mean[0][0]']
#
#  block_8_se_act_s (Lambda)      (None, 1, 1, 24)     0           ['block_8_se_conv2d_s[0][0]']
#
#  block_8_se_conv2d_e (Conv2D)   (None, 1, 1, 576)    14400       ['block_8_se_act_s[0][0]']
#
#  block_8_se_act_e (Lambda)      (None, 1, 1, 576)    0           ['block_8_se_conv2d_e[0][0]']
#
#  block_8_se_mult (Multiply)     (None, 17, 11, 576)  0           ['block_8_se_act_e[0][0]',
#                                                                   'block_8_act[0][0]']
#
#  block_8_conv2d_proj (Conv2D)   (None, 17, 11, 112)  64512       ['block_8_se_mult[0][0]']
#
#  block_8_bnorm_proj (BatchNorma  (None, 17, 11, 112)  448        ['block_8_conv2d_proj[0][0]']
#  lization)
#
#  block_9_conv2d_expand (Conv2D)  (None, 17, 11, 672)  75264      ['block_8_bnorm_proj[0][0]']
#
#  block_9_bnorm_expand (BatchNor  (None, 17, 11, 672)  2688       ['block_9_conv2d_expand[0][0]']
#  malization)
#
#  block_9_act_expand (Lambda)    (None, 17, 11, 672)  0           ['block_9_bnorm_expand[0][0]']
#
#  block_9_dwconv2d (DepthwiseCon  (None, 17, 11, 672)  6048       ['block_9_act_expand[0][0]']
#  v2D)
#
#  block_9_bnorm (BatchNormalizat  (None, 17, 11, 672)  2688       ['block_9_dwconv2d[0][0]']
#  ion)
#
#  block_9_act (Lambda)           (None, 17, 11, 672)  0           ['block_9_bnorm[0][0]']
#
#  block_9_se_mean (Lambda)       (None, 1, 1, 672)    0           ['block_9_act[0][0]']
#
#  block_9_se_conv2d_s (Conv2D)   (None, 1, 1, 28)     18844       ['block_9_se_mean[0][0]']
#
#  block_9_se_act_s (Lambda)      (None, 1, 1, 28)     0           ['block_9_se_conv2d_s[0][0]']
#
#  block_9_se_conv2d_e (Conv2D)   (None, 1, 1, 672)    19488       ['block_9_se_act_s[0][0]']
#
#  block_9_se_act_e (Lambda)      (None, 1, 1, 672)    0           ['block_9_se_conv2d_e[0][0]']
#
#  block_9_se_mult (Multiply)     (None, 17, 11, 672)  0           ['block_9_se_act_e[0][0]',
#                                                                   'block_9_act[0][0]']
#
#  block_9_conv2d_proj (Conv2D)   (None, 17, 11, 112)  75264       ['block_9_se_mult[0][0]']
#
#  block_9_bnorm_proj (BatchNorma  (None, 17, 11, 112)  448        ['block_9_conv2d_proj[0][0]']
#  lization)
#
#  block_9_stochdepth (Dropout)   (None, 17, 11, 112)  0           ['block_9_bnorm_proj[0][0]']
#
#  block_9_add (Add)              (None, 17, 11, 112)  0           ['block_8_bnorm_proj[0][0]',
#                                                                   'block_9_stochdepth[0][0]']
#
#  block_10_conv2d_expand (Conv2D  (None, 17, 11, 672)  75264      ['block_9_add[0][0]']
#  )
#
#  block_10_bnorm_expand (BatchNo  (None, 17, 11, 672)  2688       ['block_10_conv2d_expand[0][0]']
#  rmalization)
#
#  block_10_act_expand (Lambda)   (None, 17, 11, 672)  0           ['block_10_bnorm_expand[0][0]']
#
#  block_10_dwconv2d (DepthwiseCo  (None, 17, 11, 672)  6048       ['block_10_act_expand[0][0]']
#  nv2D)
#
#  block_10_bnorm (BatchNormaliza  (None, 17, 11, 672)  2688       ['block_10_dwconv2d[0][0]']
#  tion)
#
#  block_10_act (Lambda)          (None, 17, 11, 672)  0           ['block_10_bnorm[0][0]']
#
#  block_10_se_mean (Lambda)      (None, 1, 1, 672)    0           ['block_10_act[0][0]']
#
#  block_10_se_conv2d_s (Conv2D)  (None, 1, 1, 28)     18844       ['block_10_se_mean[0][0]']
#
#  block_10_se_act_s (Lambda)     (None, 1, 1, 28)     0           ['block_10_se_conv2d_s[0][0]']
#
#  block_10_se_conv2d_e (Conv2D)  (None, 1, 1, 672)    19488       ['block_10_se_act_s[0][0]']
#
#  block_10_se_act_e (Lambda)     (None, 1, 1, 672)    0           ['block_10_se_conv2d_e[0][0]']
#
#  block_10_se_mult (Multiply)    (None, 17, 11, 672)  0           ['block_10_se_act_e[0][0]',
#                                                                   'block_10_act[0][0]']
#
#  block_10_conv2d_proj (Conv2D)  (None, 17, 11, 112)  75264       ['block_10_se_mult[0][0]']
#
#  block_10_bnorm_proj (BatchNorm  (None, 17, 11, 112)  448        ['block_10_conv2d_proj[0][0]']
#  alization)
#
#  block_10_stochdepth (Dropout)  (None, 17, 11, 112)  0           ['block_10_bnorm_proj[0][0]']
#
#  block_10_add (Add)             (None, 17, 11, 112)  0           ['block_9_add[0][0]',
#                                                                   'block_10_stochdepth[0][0]']
#
#  block_11_conv2d_expand (Conv2D  (None, 17, 11, 672)  75264      ['block_10_add[0][0]']
#  )
#
#  block_11_bnorm_expand (BatchNo  (None, 17, 11, 672)  2688       ['block_11_conv2d_expand[0][0]']
#  rmalization)
#
#  block_11_act_expand (Lambda)   (None, 17, 11, 672)  0           ['block_11_bnorm_expand[0][0]']
#
#  block_11_dwconv2d (DepthwiseCo  (None, 17, 11, 672)  6048       ['block_11_act_expand[0][0]']
#  nv2D)
#
#  block_11_bnorm (BatchNormaliza  (None, 17, 11, 672)  2688       ['block_11_dwconv2d[0][0]']
#  tion)
#
#  block_11_act (Lambda)          (None, 17, 11, 672)  0           ['block_11_bnorm[0][0]']
#
#  block_11_se_mean (Lambda)      (None, 1, 1, 672)    0           ['block_11_act[0][0]']
#
#  block_11_se_conv2d_s (Conv2D)  (None, 1, 1, 28)     18844       ['block_11_se_mean[0][0]']
#
#  block_11_se_act_s (Lambda)     (None, 1, 1, 28)     0           ['block_11_se_conv2d_s[0][0]']
#
#  block_11_se_conv2d_e (Conv2D)  (None, 1, 1, 672)    19488       ['block_11_se_act_s[0][0]']
#
#  block_11_se_act_e (Lambda)     (None, 1, 1, 672)    0           ['block_11_se_conv2d_e[0][0]']
#
#  block_11_se_mult (Multiply)    (None, 17, 11, 672)  0           ['block_11_se_act_e[0][0]',
#                                                                   'block_11_act[0][0]']
#
#  block_11_conv2d_proj (Conv2D)  (None, 17, 11, 112)  75264       ['block_11_se_mult[0][0]']
#
#  block_11_bnorm_proj (BatchNorm  (None, 17, 11, 112)  448        ['block_11_conv2d_proj[0][0]']
#  alization)
#
#  block_11_stochdepth (Dropout)  (None, 17, 11, 112)  0           ['block_11_bnorm_proj[0][0]']
#
#  block_11_add (Add)             (None, 17, 11, 112)  0           ['block_10_add[0][0]',
#                                                                   'block_11_stochdepth[0][0]']
#
#  block_12_conv2d_expand (Conv2D  (None, 17, 11, 672)  75264      ['block_11_add[0][0]']
#  )
#
#  block_12_bnorm_expand (BatchNo  (None, 17, 11, 672)  2688       ['block_12_conv2d_expand[0][0]']
#  rmalization)
#
#  block_12_act_expand (Lambda)   (None, 17, 11, 672)  0           ['block_12_bnorm_expand[0][0]']
#
#  block_12_dwconv2d (DepthwiseCo  (None, 17, 11, 672)  6048       ['block_12_act_expand[0][0]']
#  nv2D)
#
#  block_12_bnorm (BatchNormaliza  (None, 17, 11, 672)  2688       ['block_12_dwconv2d[0][0]']
#  tion)
#
#  block_12_act (Lambda)          (None, 17, 11, 672)  0           ['block_12_bnorm[0][0]']
#
#  block_12_se_mean (Lambda)      (None, 1, 1, 672)    0           ['block_12_act[0][0]']
#
#  block_12_se_conv2d_s (Conv2D)  (None, 1, 1, 28)     18844       ['block_12_se_mean[0][0]']
#
#  block_12_se_act_s (Lambda)     (None, 1, 1, 28)     0           ['block_12_se_conv2d_s[0][0]']
#
#  block_12_se_conv2d_e (Conv2D)  (None, 1, 1, 672)    19488       ['block_12_se_act_s[0][0]']
#
#  block_12_se_act_e (Lambda)     (None, 1, 1, 672)    0           ['block_12_se_conv2d_e[0][0]']
#
#  block_12_se_mult (Multiply)    (None, 17, 11, 672)  0           ['block_12_se_act_e[0][0]',
#                                                                   'block_12_act[0][0]']
#
#  block_12_conv2d_proj (Conv2D)  (None, 17, 11, 112)  75264       ['block_12_se_mult[0][0]']
#
#  block_12_bnorm_proj (BatchNorm  (None, 17, 11, 112)  448        ['block_12_conv2d_proj[0][0]']
#  alization)
#
#  block_12_stochdepth (Dropout)  (None, 17, 11, 112)  0           ['block_12_bnorm_proj[0][0]']
#
#  block_12_add (Add)             (None, 17, 11, 112)  0           ['block_11_add[0][0]',
#                                                                   'block_12_stochdepth[0][0]']
#
#  block_13_conv2d_expand (Conv2D  (None, 17, 11, 672)  75264      ['block_12_add[0][0]']
#  )
#
#  block_13_bnorm_expand (BatchNo  (None, 17, 11, 672)  2688       ['block_13_conv2d_expand[0][0]']
#  rmalization)
#
#  block_13_act_expand (Lambda)   (None, 17, 11, 672)  0           ['block_13_bnorm_expand[0][0]']
#
#  block_13_dwconv2d (DepthwiseCo  (None, 9, 6, 672)   6048        ['block_13_act_expand[0][0]']
#  nv2D)
#
#  block_13_bnorm (BatchNormaliza  (None, 9, 6, 672)   2688        ['block_13_dwconv2d[0][0]']
#  tion)
#
#  block_13_act (Lambda)          (None, 9, 6, 672)    0           ['block_13_bnorm[0][0]']
#
#  block_13_se_mean (Lambda)      (None, 1, 1, 672)    0           ['block_13_act[0][0]']
#
#  block_13_se_conv2d_s (Conv2D)  (None, 1, 1, 28)     18844       ['block_13_se_mean[0][0]']
#
#  block_13_se_act_s (Lambda)     (None, 1, 1, 28)     0           ['block_13_se_conv2d_s[0][0]']
#
#  block_13_se_conv2d_e (Conv2D)  (None, 1, 1, 672)    19488       ['block_13_se_act_s[0][0]']
#
#  block_13_se_act_e (Lambda)     (None, 1, 1, 672)    0           ['block_13_se_conv2d_e[0][0]']
#
#  block_13_se_mult (Multiply)    (None, 9, 6, 672)    0           ['block_13_se_act_e[0][0]',
#                                                                   'block_13_act[0][0]']
#
#  block_13_conv2d_proj (Conv2D)  (None, 9, 6, 192)    129024      ['block_13_se_mult[0][0]']
#
#  block_13_bnorm_proj (BatchNorm  (None, 9, 6, 192)   768         ['block_13_conv2d_proj[0][0]']
#  alization)
#
#  block_14_conv2d_expand (Conv2D  (None, 9, 6, 1152)  221184      ['block_13_bnorm_proj[0][0]']
#  )
#
#  block_14_bnorm_expand (BatchNo  (None, 9, 6, 1152)  4608        ['block_14_conv2d_expand[0][0]']
#  rmalization)
#
#  block_14_act_expand (Lambda)   (None, 9, 6, 1152)   0           ['block_14_bnorm_expand[0][0]']
#
#  block_14_dwconv2d (DepthwiseCo  (None, 9, 6, 1152)  10368       ['block_14_act_expand[0][0]']
#  nv2D)
#
#  block_14_bnorm (BatchNormaliza  (None, 9, 6, 1152)  4608        ['block_14_dwconv2d[0][0]']
#  tion)
#
#  block_14_act (Lambda)          (None, 9, 6, 1152)   0           ['block_14_bnorm[0][0]']
#
#  block_14_se_mean (Lambda)      (None, 1, 1, 1152)   0           ['block_14_act[0][0]']
#
#  block_14_se_conv2d_s (Conv2D)  (None, 1, 1, 48)     55344       ['block_14_se_mean[0][0]']
#
#  block_14_se_act_s (Lambda)     (None, 1, 1, 48)     0           ['block_14_se_conv2d_s[0][0]']
#
#  block_14_se_conv2d_e (Conv2D)  (None, 1, 1, 1152)   56448       ['block_14_se_act_s[0][0]']
#
#  block_14_se_act_e (Lambda)     (None, 1, 1, 1152)   0           ['block_14_se_conv2d_e[0][0]']
#
#  block_14_se_mult (Multiply)    (None, 9, 6, 1152)   0           ['block_14_se_act_e[0][0]',
#                                                                   'block_14_act[0][0]']
#
#  block_14_conv2d_proj (Conv2D)  (None, 9, 6, 192)    221184      ['block_14_se_mult[0][0]']
#
#  block_14_bnorm_proj (BatchNorm  (None, 9, 6, 192)   768         ['block_14_conv2d_proj[0][0]']
#  alization)
#
#  block_14_stochdepth (Dropout)  (None, 9, 6, 192)    0           ['block_14_bnorm_proj[0][0]']
#
#  block_14_add (Add)             (None, 9, 6, 192)    0           ['block_13_bnorm_proj[0][0]',
#                                                                   'block_14_stochdepth[0][0]']
#
#  block_15_conv2d_expand (Conv2D  (None, 9, 6, 1152)  221184      ['block_14_add[0][0]']
#  )
#
#  block_15_bnorm_expand (BatchNo  (None, 9, 6, 1152)  4608        ['block_15_conv2d_expand[0][0]']
#  rmalization)
#
#  block_15_act_expand (Lambda)   (None, 9, 6, 1152)   0           ['block_15_bnorm_expand[0][0]']
#
#  block_15_dwconv2d (DepthwiseCo  (None, 9, 6, 1152)  10368       ['block_15_act_expand[0][0]']
#  nv2D)
#
#  block_15_bnorm (BatchNormaliza  (None, 9, 6, 1152)  4608        ['block_15_dwconv2d[0][0]']
#  tion)
#
#  block_15_act (Lambda)          (None, 9, 6, 1152)   0           ['block_15_bnorm[0][0]']
#
#  block_15_se_mean (Lambda)      (None, 1, 1, 1152)   0           ['block_15_act[0][0]']
#
#  block_15_se_conv2d_s (Conv2D)  (None, 1, 1, 48)     55344       ['block_15_se_mean[0][0]']
#
# ...
# 280/280 [==============================] - 37s 132ms/step - loss: 0.6694 - accuracy: 0.8636 - val_loss: 1.4016 - val_accuracy: 0.5071
# Epoch 94/200
# 280/280 [==============================] - 37s 133ms/step - loss: 0.6492 - accuracy: 0.8780 - val_loss: 1.3784 - val_accuracy: 0.5165
# Epoch 95/200
# 280/280 [==============================] - 37s 131ms/step - loss: 0.6563 - accuracy: 0.8723 - val_loss: 1.3896 - val_accuracy: 0.5121
# Epoch 96/200
# 280/280 [==============================] - 37s 131ms/step - loss: 0.6585 - accuracy: 0.8761 - val_loss: 1.3700 - val_accuracy: 0.5089
# Epoch 97/200
# 280/280 [==============================] - 37s 131ms/step - loss: 0.6589 - accuracy: 0.8753 - val_loss: 1.3824 - val_accuracy: 0.5071
# Epoch 98/200
# 280/280 [==============================] - 37s 132ms/step - loss: 0.6557 - accuracy: 0.8741 - val_loss: 1.4026 - val_accuracy: 0.5223
# Epoch 99/200
# 280/280 [==============================] - 37s 131ms/step - loss: 0.6505 - accuracy: 0.8796 - val_loss: 1.3993 - val_accuracy: 0.5156
# Epoch 100/200
# 280/280 [==============================] - 37s 134ms/step - loss: 0.6452 - accuracy: 0.8805 - val_loss: 1.4023 - val_accuracy: 0.5129
# Epoch 101/200
# 280/280 [==============================] - 37s 131ms/step - loss: 0.6510 - accuracy: 0.8775 - val_loss: 1.4018 - val_accuracy: 0.5161
# Epoch 102/200
# 280/280 [==============================] - 37s 131ms/step - loss: 0.6446 - accuracy: 0.8807 - val_loss: 1.3851 - val_accuracy: 0.5183
# Epoch 103/200
# 280/280 [==============================] - 37s 132ms/step - loss: 0.6390 - accuracy: 0.8854 - val_loss: 1.4178 - val_accuracy: 0.5143
# Epoch 104/200
# 280/280 [==============================] - 37s 132ms/step - loss: 0.6437 - accuracy: 0.8770 - val_loss: 1.4112 - val_accuracy: 0.5107
# Epoch 105/200
# 280/280 [==============================] - 37s 131ms/step - loss: 0.6356 - accuracy: 0.8888 - val_loss: 1.4168 - val_accuracy: 0.5054
# Epoch 106/200
# 280/280 [==============================] - 37s 132ms/step - loss: 0.6291 - accuracy: 0.8925 - val_loss: 1.4311 - val_accuracy: 0.4982
# Epoch 107/200
# 280/280 [==============================] - 37s 132ms/step - loss: 0.6238 - accuracy: 0.8944 - val_loss: 1.4430 - val_accuracy: 0.5045
# Epoch 108/200
# 280/280 [==============================] - 37s 134ms/step - loss: 0.6256 - accuracy: 0.8920 - val_loss: 1.4228 - val_accuracy: 0.5027
# Epoch 109/200
# 280/280 [==============================] - 37s 131ms/step - loss: 0.6266 - accuracy: 0.8919 - val_loss: 1.3755 - val_accuracy: 0.5156
# Epoch 110/200
# 280/280 [==============================] - 37s 131ms/step - loss: 0.6223 - accuracy: 0.8939 - val_loss: 1.4173 - val_accuracy: 0.5152
# Epoch 190/200
# 280/280 [==============================] - 37s 132ms/step - loss: 0.5252 - accuracy: 0.9396 - val_loss: 1.4990 - val_accuracy: 0.5188
# Epoch 191/200
# 280/280 [==============================] - 37s 131ms/step - loss: 0.5204 - accuracy: 0.9463 - val_loss: 1.4539 - val_accuracy: 0.5147
# Epoch 192/200
# 280/280 [==============================] - 37s 133ms/step - loss: 0.5294 - accuracy: 0.9388 - val_loss: 1.4468 - val_accuracy: 0.5156
# Epoch 193/200
# 280/280 [==============================] - 37s 132ms/step - loss: 0.5229 - accuracy: 0.9435 - val_loss: 1.4654 - val_accuracy: 0.5232
# Epoch 194/200
# 280/280 [==============================] - 37s 133ms/step - loss: 0.5274 - accuracy: 0.9402 - val_loss: 1.4363 - val_accuracy: 0.5134
# Epoch 195/200
# 280/280 [==============================] - 38s 134ms/step - loss: 0.5256 - accuracy: 0.9406 - val_loss: 1.4881 - val_accuracy: 0.5089
# Epoch 196/200
# 280/280 [==============================] - 37s 132ms/step - loss: 0.5175 - accuracy: 0.9422 - val_loss: 1.4632 - val_accuracy: 0.5089
# Epoch 197/200
# 280/280 [==============================] - 37s 132ms/step - loss: 0.5216 - accuracy: 0.9412 - val_loss: 1.4543 - val_accuracy: 0.5040
# Epoch 198/200
# 280/280 [==============================] - 37s 132ms/step - loss: 0.5231 - accuracy: 0.9412 - val_loss: 1.4341 - val_accuracy: 0.5161
# Epoch 199/200
# 280/280 [==============================] - 37s 132ms/step - loss: 0.5211 - accuracy: 0.9424 - val_loss: 1.4910 - val_accuracy: 0.5036
# Epoch 200/200
# 280/280 [==============================] - 37s 132ms/step - loss: 0.5168 - accuracy: 0.9448 - val_loss: 1.4446 - val_accuracy: 0.5214
# [TIME ] 7614.066701889038 s

# %%
from matplotlib import pyplot as plt
def get_class_string_from_index(index):
   for class_string, class_index in valid_generator.class_indices.items():
      if class_index == index:
         return class_string

x, y = next(valid_generator)
image = x[0, :, :, :]
true_index = np.argmax(y[0])
plt.imshow(image)
plt.axis('off')
plt.show()

# Expand the validation image to (1, 224, 224, 3) before predicting the label
prediction_scores = model.predict(np.expand_dims(image, axis=0))
predicted_index = np.argmax(prediction_scores)
print("True label: " + get_class_string_from_index(true_index))
print("Predicted label: " + get_class_string_from_index(predicted_index))
# Out:
# True label: Q1
# Predicted label: Q4

# %%
model.save(RESEARCH_WORK_PATH + "models/efficient_net_v2_vanilla")
# Out:
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/BachelorResearch/models/efficient_net_v2_vanilla/assets

# %%
# 学習状況のプロット関数の定義
def plot_history(history):
    # 分類精度の履歴をプロット
    plt.plot(history['accuracy'])
    plt.plot(history['val_accuracy'])
    plt.title('model accuracy')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.legend(['training', 'validation'], loc='lower right')
    plt.show()

    # 損失関数の履歴をプロット
    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    plt.title('model loss')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['training', 'validation'], loc='upper right')
    plt.show()

plot_history(hist)
