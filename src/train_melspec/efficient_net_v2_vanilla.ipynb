# %%
# Initializing
from google.colab import drive
import re
import math
from keras import layers
import copy

drive.mount('/content/drive')
# Define constant value
RESEARCH_WORK_PATH = "/content/drive/My Drive/Colab Notebooks/BachelorResearch/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
"""EfficientNet V1 and V2 model configs."""

#################### EfficientNet V1 configs ####################
v1_b0_block_str = [
        'r1_k3_s1_e1_i32_o16_se0.25',
        'r2_k3_s2_e6_i16_o24_se0.25',
        'r2_k5_s2_e6_i24_o40_se0.25',
        'r3_k3_s2_e6_i40_o80_se0.25',
        'r3_k5_s1_e6_i80_o112_se0.25',
        'r4_k5_s2_e6_i112_o192_se0.25',
        'r1_k3_s1_e6_i192_o320_se0.25',
]

#################### EfficientNet V2 configs ####################
v2_base_block = [    # The baseline config for v2 models.
        'r1_k3_s1_e1_i32_o16_c1',
        'r2_k3_s2_e4_i16_o32_c1',
        'r2_k3_s2_e4_i32_o48_c1',
        'r3_k3_s2_e4_i48_o96_se0.25',
        'r5_k3_s1_e6_i96_o112_se0.25',
        'r8_k3_s2_e6_i112_o192_se0.25',
]

v2_s_block = [    # about base * (width1.4, depth1.8)
        'r2_k3_s1_e1_i24_o24_c1',
        'r4_k3_s2_e4_i24_o48_c1',
        'r4_k3_s2_e4_i48_o64_c1',
        'r6_k3_s2_e4_i64_o128_se0.25',
        'r9_k3_s1_e6_i128_o160_se0.25',
        'r15_k3_s2_e6_i160_o256_se0.25',
]


v2_m_block = [    # about base * (width1.6, depth2.2)
        'r3_k3_s1_e1_i24_o24_c1',
        'r5_k3_s2_e4_i24_o48_c1',
        'r5_k3_s2_e4_i48_o80_c1',
        'r7_k3_s2_e4_i80_o160_se0.25',
        'r14_k3_s1_e6_i160_o176_se0.25',
        'r18_k3_s2_e6_i176_o304_se0.25',
        'r5_k3_s1_e6_i304_o512_se0.25',
]


v2_l_block = [    # about base * (width2.0, depth3.1)
        'r4_k3_s1_e1_i32_o32_c1',
        'r7_k3_s2_e4_i32_o64_c1',
        'r7_k3_s2_e4_i64_o96_c1',
        'r10_k3_s2_e4_i96_o192_se0.25',
        'r19_k3_s1_e6_i192_o224_se0.25',
        'r25_k3_s2_e6_i224_o384_se0.25',
        'r7_k3_s1_e6_i384_o640_se0.25',
]

v2_xl_block = [    # only for 21k pretraining.
        'r4_k3_s1_e1_i32_o32_c1',
        'r8_k3_s2_e4_i32_o64_c1',
        'r8_k3_s2_e4_i64_o96_c1',
        'r16_k3_s2_e4_i96_o192_se0.25',
        'r24_k3_s1_e6_i192_o256_se0.25',
        'r32_k3_s2_e6_i256_o512_se0.25',
        'r8_k3_s1_e6_i512_o640_se0.25',
]
efficientnet_params = {
        # (block, width, depth, train_size, eval_size, dropout, randaug, mixup, aug)
        'efficientnetv2-s':    # 83.9% @ 22M
                (v2_s_block, 1.0, 1.0, 300, 384, 0.2, 10, 0, 'randaug'),
        'efficientnetv2-m':    # 85.2% @ 54M
                (v2_m_block, 1.0, 1.0, 384, 480, 0.3, 15, 0.2, 'randaug'),
        'efficientnetv2-l':    # 85.7% @ 120M
                (v2_l_block, 1.0, 1.0, 384, 480, 0.4, 20, 0.5, 'randaug'),

        'efficientnetv2-xl':
                (v2_xl_block, 1.0, 1.0, 384, 512, 0.4, 20, 0.5, 'randaug'),

        # For fair comparison to EfficientNetV1, using the same scaling and autoaug.
        'efficientnetv2-b0':    # 78.7% @ 7M params
                (v2_base_block, 1.0, 1.0, 192, 224, 0.2, 0, 0, 'effnetv1_autoaug'),
        'efficientnetv2-b1':    # 79.8% @ 8M params
                (v2_base_block, 1.0, 1.1, 192, 240, 0.2, 0, 0, 'effnetv1_autoaug'),
        'efficientnetv2-b2':    # 80.5% @ 10M params
                (v2_base_block, 1.1, 1.2, 208, 260, 0.3, 0, 0, 'effnetv1_autoaug'),
        'efficientnetv2-b3':    # 82.1% @ 14M params
                (v2_base_block, 1.2, 1.4, 240, 300, 0.3, 0, 0, 'effnetv1_autoaug'),

        'efficientnet-b0': (v1_b0_block_str, 1.0, 1.0, 224, 224, 0.2),
        'efficientnet-b1': (v1_b0_block_str, 1.0, 1.1, 240, 240, 0.2),
        'efficientnet-b2': (v1_b0_block_str, 1.1, 1.2, 260, 260, 0.3),
        'efficientnet-b3': (v1_b0_block_str, 1.2, 1.4, 300, 300, 0.3),
        'efficientnet-b4': (v1_b0_block_str, 1.4, 1.8, 380, 380, 0.4),
        'efficientnet-b5': (v1_b0_block_str, 1.6, 2.2, 456, 456, 0.4),
        'efficientnet-b6': (v1_b0_block_str, 1.8, 2.6, 528, 528, 0.5),
        'efficientnet-b7': (v1_b0_block_str, 2.0, 3.1, 600, 600, 0.5),
        'efficientnet-b8': (v1_b0_block_str, 2.2, 3.6, 672, 672, 0.5),
        'efficientnet-l2': (v1_b0_block_str, 4.3, 5.3, 800, 800, 0.5),
}



class Struct:
        def __init__(self, **entries):
                self.__dict__.update(entries)

def make_config(model_name):
    def round_filters(filters, multiplier, divisor, min_depth=None, skip=False):
        """Round number of filters based on depth multiplier."""
        if skip or not multiplier:
            return filters

        filters = filters*multiplier
        min_depth = min_depth or divisor
        new_filters = max(min_depth, int(filters + divisor / 2) // divisor * divisor)
        return int(new_filters)


    def round_repeats(repeats, multiplier, skip=False):
        """Round number of filters based on depth multiplier."""
        if skip or not multiplier:
            return repeats
        return int(math.ceil(multiplier * repeats))    

    cfg = efficientnet_params[model_name]
    width_coefficient = cfg[1]
    depth_coefficient = cfg[2] 

    block_args_list = []
    for block_string in cfg[0]:
        ops = block_string.split('_')
        options = {}
        for op in ops:
            splits = re.split(r'(\d.*)', op)
            if len(splits) >= 2:
                key, value = splits[:2]
                options[key] = value

        input_filters = round_filters(int(options['i']), width_coefficient, 8)
        output_filters = round_filters(int(options['o']), width_coefficient, 8)

        block0_args =    Struct(
                kernel_size=int(options['k']),
                input_filters=input_filters,
                output_filters=output_filters,
                expand_ratio=int(options['e']),
                se_ratio=float(options['se']) if 'se' in options else 0.0,
                strides=int(options['s']),
                conv_type=int(options['c']) if 'c' in options else 0,
        )

        block_args_list.append(block0_args)
        repeats = round_repeats(int(options['r']), depth_coefficient)
        for _ in range(repeats - 1):
            block_args = copy.deepcopy(block0_args)
            block_args.input_filters=int(output_filters)
            block_args.strides=int(1)
            block_args_list.append(block_args)

    mconfig = Struct(
        name=model_name,
        block_args_list = block_args_list,
        train_size = cfg[3],
        eval_size = cfg[4],
        dropout_rate = cfg[5],
        num_classes = 4,  # changed 1000 to 4
        feature_size = round_filters( 1280, width_coefficient, 8),
        depth_divisor = 8,
        bn_momentum = 0.9,
        bn_epsilon = 1e-3,
        min_depth = 8,
        survival_prob = 0.8,
        weight_decay = 0.0,
        stem_stride=2,

    )
    return mconfig

# %%
def conv_kernel_initializer(shape, dtype=None, partition_info=None):
    del partition_info
    kernel_height, kernel_width, _, out_filters = shape
    fan_out = int(kernel_height * kernel_width * out_filters)
    return tf.random.normal(
            shape, mean=0.0, stddev=np.sqrt(2.0 / fan_out), dtype=dtype)

def dense_kernel_initializer(shape, dtype=None, partition_info=None):
    del partition_info
    init_range = 1.0 / np.sqrt(shape[1])
    return tf.random.uniform(shape, -init_range, init_range, dtype=dtype)

def create_efficientnet(config, input_shape=(None,None,3) , name=None, verbose=0):
    mconfig = config
    BN_KWARGS = {'momentum':mconfig.bn_momentum, 'epsilon':mconfig.bn_epsilon}
    CONV_KWARGS = {'use_bias':False, 'padding':'same', 
                    'kernel_initializer': conv_kernel_initializer, 
                    'kernel_regularizer': tf.keras.regularizers.l2(mconfig.weight_decay)}

    def activation(fn='silu', name=None):
        if fn=='sigmoid':
            return layers.Lambda( lambda y: tf.sigmoid(y), name=name)
        return layers.Lambda( lambda y: tf.nn.silu(y), name=name)

    def conv_bn_act(x, filters, kernel, stride, prefix):
        x = layers.Conv2D( filters, kernel, stride, name=prefix+'_conv2d',    **CONV_KWARGS)(x)
        x = layers.BatchNormalization(name=prefix+'_bnorm', **BN_KWARGS)(x)
        x = activation(name=prefix+'_act')(x)
        return x

    def se(inputs, se_filters, filters, prefix):
        SE_CONV_KWARGS = {'use_bias':True, 'padding':'same', 
                        'kernel_initializer': conv_kernel_initializer,
                        'kernel_regularizer': tf.keras.regularizers.l2(mconfig.weight_decay)}
        x = layers.Lambda(lambda y:tf.reduce_mean(y, [1, 2], keepdims=True), name=prefix+'_se_mean')(inputs)
        x = layers.Conv2D(se_filters, 1, 1, name=prefix+'_se_conv2d_s', **SE_CONV_KWARGS)(x)
        x = activation(name=prefix+'_se_act_s')(x)
        x = layers.Conv2D(filters, 1, 1, name=prefix+'_se_conv2d_e', **SE_CONV_KWARGS)(x)
        x = activation('sigmoid', name=prefix+'_se_act_e')(x)
        x = layers.Multiply(name=prefix+'_se_mult')( [x ,inputs ])
        return x

    def mb_conv(inputs, block_args, prefix):
        filters = block_args.input_filters * block_args.expand_ratio
        se_filters = int(block_args.input_filters*block_args.se_ratio)
        x = inputs
        if block_args.expand_ratio != 1:
            x = layers.Conv2D( filters, 1, 1, name=prefix+'_conv2d_expand', **CONV_KWARGS)(x)
            x = layers.BatchNormalization(name=prefix+'_bnorm_expand', **BN_KWARGS)(x)
            x = activation(name=prefix+'_act_expand')(x)

        x = layers.DepthwiseConv2D( block_args.kernel_size, block_args.strides, name=prefix+'_dwconv2d', **CONV_KWARGS)(x)
        x = layers.BatchNormalization(name=prefix+'_bnorm', **BN_KWARGS)(x)
        x = activation(name=prefix+'_act')(x)
        if se_filters!=0:
            x = se(x, se_filters, filters, prefix=prefix)
        x = layers.Conv2D( block_args.output_filters, 1, 1, name=prefix+'_conv2d_proj', **CONV_KWARGS)(x)
        x = layers.BatchNormalization(name=prefix+'_bnorm_proj', **BN_KWARGS)(x)

        return x

    def fused_mb_conv(inputs, block_args, prefix):
        filters = block_args.input_filters * block_args.expand_ratio
        se_filters = int(block_args.input_filters*block_args.se_ratio)
        x = inputs
        if block_args.expand_ratio != 1:
            x = layers.Conv2D( filters, block_args.kernel_size, block_args.strides, 
                name=prefix+'_conv2d_expand', **CONV_KWARGS)(x)
            x = layers.BatchNormalization(name=prefix+'_bnorm_expand', **BN_KWARGS)(x)
            x = activation(name=prefix+'_act_expand')(x)
            if se_filters!=0:
                x = se(x, se_filters, filters, prefix=prefix)
            x = layers.Conv2D( block_args.output_filters, 1, 1, 
                name = prefix+'_conv2d', **CONV_KWARGS )(x)
            x = layers.BatchNormalization(name=prefix+'_bnorm', **BN_KWARGS)(x)
        else:
            if se_filters!=0:
                x = se(x, se_filters, filters, prefix=prefix)
            x = layers.Conv2D( block_args.output_filters, block_args.kernel_size, block_args.strides,
                name = prefix+'_conv2d', **CONV_KWARGS )(x)
            x = layers.BatchNormalization(name=prefix+'_bnorm', **BN_KWARGS)(x)
            x = activation(name=prefix+'_act')(x) # add act if no expansion.

        return x

    # Input
    x = input = tf.keras.Input(shape=input_shape, name='input')


    # Stem
    stem_filters = mconfig.block_args_list[0].input_filters
    x = conv_bn_act(x, stem_filters , 3, mconfig.stem_stride, prefix='stem')
    if verbose!=0:
        print('stem', 3, stem_filters, mconfig.stem_stride )

    # Blocks
    for i, block_args in enumerate(mconfig.block_args_list):
        shortcut = x
        if block_args.conv_type==0:
            prefix = f'block_{i}'
            x = mb_conv(x, block_args, prefix)
        else:
            prefix = f'block_{i}_fused'
            x = fused_mb_conv(x, block_args, prefix)

        survival_prob = mconfig.survival_prob
        if block_args.strides == 1 and block_args.input_filters==block_args.output_filters:
            if survival_prob:
                # StochasticDepth
                drop_rate = 1.0 - survival_prob
                drop_rate = drop_rate * float(i+1) / len(mconfig.block_args_list)
                survival_prob = 1.0 - drop_rate
                x = layers.Dropout(rate=drop_rate, noise_shape=(None,1,1,1), name=prefix+'_stochdepth')(x)
            x = layers.Add(name=prefix+'_add')([shortcut,x])
        else:
            survival_prob = None

        if verbose!=0:
            print(i, block_args.kernel_size,block_args.input_filters, block_args.output_filters, 
                block_args.strides, block_args.expand_ratio, survival_prob    )

    # Head
    x = conv_bn_act( x,mconfig.feature_size , 1, 1, prefix='head')
    x = layers.GlobalAveragePooling2D(name='head_gap')(x)
    if mconfig.dropout_rate > 0:
        x = layers.Dropout(mconfig.dropout_rate,name='head_dropout')(x)
    output = layers.Dense(mconfig.num_classes,
            kernel_initializer = dense_kernel_initializer,
            kernel_regularizer = tf.keras.regularizers.l2(mconfig.weight_decay),
            use_bias = True, name='head_fc')(x)
    if verbose!=0:
        print('head', mconfig.feature_size, mconfig.num_classes, mconfig.dropout_rate    )

    model = tf.keras.Model(inputs=[input], outputs=[output], name=name)
    if verbose!=0:
        print('params', model.count_params())
    return model

# %%
import shutil
import os

if os.path.exists("/content/datas/"):
  shutil.rmtree("/content/datas/")
shutil.copytree(RESEARCH_WORK_PATH + "MER_audio_taffc_dataset_wav/2s/melspectro_img/", "/content/datas/")
data_dir = "/content/datas/"

# %%
# data_dir = tf.keras.utils.get_file(
#     'flower_photos',
#     'https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz',
#     untar=True)
import tensorflow as tf
data_dir = RESEARCH_WORK_PATH + "MER_audio_taffc_dataset_wav/2s/melspectro_img/"
    
# get size of img
import cv2
sample = data_dir + "/Q1/Q1.MT0000040632_1.jpg"
i = cv2.imread(sample)
(img_row, img_col, c) = i.shape
    
datagen_kwargs = dict(rescale=1./255, validation_split=.20)
batch_size = 32
dataflow_kwargs = dict(target_size=(img_row, img_col),
                       batch_size=batch_size,
                       interpolation="bilinear")


valid_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    **datagen_kwargs)
valid_generator = valid_datagen.flow_from_directory(
    data_dir, subset="validation", shuffle=False, **dataflow_kwargs)
print(data_dir)

do_data_augmentation = False #@param {type:"boolean"}
if do_data_augmentation:
  train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
      rotation_range=40,
      horizontal_flip=True,
      width_shift_range=0.2, height_shift_range=0.2,
      shear_range=0.2, zoom_range=0.2,
      **datagen_kwargs)
else:
  train_datagen = valid_datagen
train_generator = train_datagen.flow_from_directory(
    data_dir, subset="training", shuffle=True, **dataflow_kwargs)
# Out:
# Found 2240 images belonging to 4 classes.
# /content/drive/My Drive/Colab Notebooks/BachelorResearch/MER_audio_taffc_dataset_wav/2s/melspectro_img/
# Found 8960 images belonging to 4 classes.

# %%
# whether to finetune the whole model or just the top layer.
import numpy as np
num_epochs = 12 #@param {type:"integer"}

tf.keras.backend.clear_session()
config = make_config("efficientnetv2-b0")
model = create_efficientnet(config, input_shape=(img_row,img_col,3))
model.summary()

model.compile(
  optimizer=tf.keras.optimizers.SGD(learning_rate=0.005, momentum=0.9), 
  loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True, label_smoothing=0.1),
  metrics=['accuracy'])

steps_per_epoch = train_generator.samples // train_generator.batch_size
validation_steps = valid_generator.samples // valid_generator.batch_size

hist = model.fit(
    train_generator,
    epochs=num_epochs, steps_per_epoch=steps_per_epoch,
    validation_data=valid_generator,
    validation_steps=validation_steps).history
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 128, 173, 3  0           []
#                                 )]
#
#  stem_conv2d (Conv2D)           (None, 64, 87, 32)   864         ['input[0][0]']
#
#  stem_bnorm (BatchNormalization  (None, 64, 87, 32)  128         ['stem_conv2d[0][0]']
#  )
#
#  stem_act (Lambda)              (None, 64, 87, 32)   0           ['stem_bnorm[0][0]']
#
#  block_0_fused_conv2d (Conv2D)  (None, 64, 87, 16)   4608        ['stem_act[0][0]']
#
#  block_0_fused_bnorm (BatchNorm  (None, 64, 87, 16)  64          ['block_0_fused_conv2d[0][0]']
#  alization)
#
#  block_0_fused_act (Lambda)     (None, 64, 87, 16)   0           ['block_0_fused_bnorm[0][0]']
#
#  block_1_fused_conv2d_expand (C  (None, 32, 44, 64)  9216        ['block_0_fused_act[0][0]']
#  onv2D)
#
#  block_1_fused_bnorm_expand (Ba  (None, 32, 44, 64)  256         ['block_1_fused_conv2d_expand[0][
#  tchNormalization)                                               0]']
#
#  block_1_fused_act_expand (Lamb  (None, 32, 44, 64)  0           ['block_1_fused_bnorm_expand[0][0
#  da)                                                             ]']
#
#  block_1_fused_conv2d (Conv2D)  (None, 32, 44, 32)   2048        ['block_1_fused_act_expand[0][0]'
#                                                                  ]
#
#  block_1_fused_bnorm (BatchNorm  (None, 32, 44, 32)  128         ['block_1_fused_conv2d[0][0]']
#  alization)
#
#  block_2_fused_conv2d_expand (C  (None, 32, 44, 128)  36864      ['block_1_fused_bnorm[0][0]']
#  onv2D)
#
#  block_2_fused_bnorm_expand (Ba  (None, 32, 44, 128)  512        ['block_2_fused_conv2d_expand[0][
#  tchNormalization)                                               0]']
#
#  block_2_fused_act_expand (Lamb  (None, 32, 44, 128)  0          ['block_2_fused_bnorm_expand[0][0
#  da)                                                             ]']
#
#  block_2_fused_conv2d (Conv2D)  (None, 32, 44, 32)   4096        ['block_2_fused_act_expand[0][0]'
#                                                                  ]
#
#  block_2_fused_bnorm (BatchNorm  (None, 32, 44, 32)  128         ['block_2_fused_conv2d[0][0]']
#  alization)
#
#  block_2_fused_stochdepth (Drop  (None, 32, 44, 32)  0           ['block_2_fused_bnorm[0][0]']
#  out)
#
#  block_2_fused_add (Add)        (None, 32, 44, 32)   0           ['block_1_fused_bnorm[0][0]',
#                                                                   'block_2_fused_stochdepth[0][0]'
#                                                                  ]
#
#  block_3_fused_conv2d_expand (C  (None, 16, 22, 128)  36864      ['block_2_fused_add[0][0]']
#  onv2D)
#
#  block_3_fused_bnorm_expand (Ba  (None, 16, 22, 128)  512        ['block_3_fused_conv2d_expand[0][
#  tchNormalization)                                               0]']
#
#  block_3_fused_act_expand (Lamb  (None, 16, 22, 128)  0          ['block_3_fused_bnorm_expand[0][0
#  da)                                                             ]']
#
#  block_3_fused_conv2d (Conv2D)  (None, 16, 22, 48)   6144        ['block_3_fused_act_expand[0][0]'
#                                                                  ]
#
#  block_3_fused_bnorm (BatchNorm  (None, 16, 22, 48)  192         ['block_3_fused_conv2d[0][0]']
#  alization)
#
#  block_4_fused_conv2d_expand (C  (None, 16, 22, 192)  82944      ['block_3_fused_bnorm[0][0]']
#  onv2D)
#
#  block_4_fused_bnorm_expand (Ba  (None, 16, 22, 192)  768        ['block_4_fused_conv2d_expand[0][
#  tchNormalization)                                               0]']
#
#  block_4_fused_act_expand (Lamb  (None, 16, 22, 192)  0          ['block_4_fused_bnorm_expand[0][0
#  da)                                                             ]']
#
#  block_4_fused_conv2d (Conv2D)  (None, 16, 22, 48)   9216        ['block_4_fused_act_expand[0][0]'
#                                                                  ]
#
#  block_4_fused_bnorm (BatchNorm  (None, 16, 22, 48)  192         ['block_4_fused_conv2d[0][0]']
#  alization)
#
#  block_4_fused_stochdepth (Drop  (None, 16, 22, 48)  0           ['block_4_fused_bnorm[0][0]']
#  out)
#
#  block_4_fused_add (Add)        (None, 16, 22, 48)   0           ['block_3_fused_bnorm[0][0]',
#                                                                   'block_4_fused_stochdepth[0][0]'
#                                                                  ]
#
#  block_5_conv2d_expand (Conv2D)  (None, 16, 22, 192)  9216       ['block_4_fused_add[0][0]']
#
#  block_5_bnorm_expand (BatchNor  (None, 16, 22, 192)  768        ['block_5_conv2d_expand[0][0]']
#  malization)
#
#  block_5_act_expand (Lambda)    (None, 16, 22, 192)  0           ['block_5_bnorm_expand[0][0]']
#
#  block_5_dwconv2d (DepthwiseCon  (None, 8, 11, 192)  1728        ['block_5_act_expand[0][0]']
#  v2D)
#
#  block_5_bnorm (BatchNormalizat  (None, 8, 11, 192)  768         ['block_5_dwconv2d[0][0]']
#  ion)
#
#  block_5_act (Lambda)           (None, 8, 11, 192)   0           ['block_5_bnorm[0][0]']
#
#  block_5_se_mean (Lambda)       (None, 1, 1, 192)    0           ['block_5_act[0][0]']
#
#  block_5_se_conv2d_s (Conv2D)   (None, 1, 1, 12)     2316        ['block_5_se_mean[0][0]']
#
#  block_5_se_act_s (Lambda)      (None, 1, 1, 12)     0           ['block_5_se_conv2d_s[0][0]']
#
#  block_5_se_conv2d_e (Conv2D)   (None, 1, 1, 192)    2496        ['block_5_se_act_s[0][0]']
#
#  block_5_se_act_e (Lambda)      (None, 1, 1, 192)    0           ['block_5_se_conv2d_e[0][0]']
#
#  block_5_se_mult (Multiply)     (None, 8, 11, 192)   0           ['block_5_se_act_e[0][0]',
#                                                                   'block_5_act[0][0]']
#
#  block_5_conv2d_proj (Conv2D)   (None, 8, 11, 96)    18432       ['block_5_se_mult[0][0]']
#
#  block_5_bnorm_proj (BatchNorma  (None, 8, 11, 96)   384         ['block_5_conv2d_proj[0][0]']
#  lization)
#
#  block_6_conv2d_expand (Conv2D)  (None, 8, 11, 384)  36864       ['block_5_bnorm_proj[0][0]']
#
#  block_6_bnorm_expand (BatchNor  (None, 8, 11, 384)  1536        ['block_6_conv2d_expand[0][0]']
#  malization)
#
#  block_6_act_expand (Lambda)    (None, 8, 11, 384)   0           ['block_6_bnorm_expand[0][0]']
#
#  block_6_dwconv2d (DepthwiseCon  (None, 8, 11, 384)  3456        ['block_6_act_expand[0][0]']
#  v2D)
#
#  block_6_bnorm (BatchNormalizat  (None, 8, 11, 384)  1536        ['block_6_dwconv2d[0][0]']
#  ion)
#
#  block_6_act (Lambda)           (None, 8, 11, 384)   0           ['block_6_bnorm[0][0]']
#
#  block_6_se_mean (Lambda)       (None, 1, 1, 384)    0           ['block_6_act[0][0]']
#
#  block_6_se_conv2d_s (Conv2D)   (None, 1, 1, 24)     9240        ['block_6_se_mean[0][0]']
#
#  block_6_se_act_s (Lambda)      (None, 1, 1, 24)     0           ['block_6_se_conv2d_s[0][0]']
#
#  block_6_se_conv2d_e (Conv2D)   (None, 1, 1, 384)    9600        ['block_6_se_act_s[0][0]']
#
#  block_6_se_act_e (Lambda)      (None, 1, 1, 384)    0           ['block_6_se_conv2d_e[0][0]']
#
#  block_6_se_mult (Multiply)     (None, 8, 11, 384)   0           ['block_6_se_act_e[0][0]',
#                                                                   'block_6_act[0][0]']
#
#  block_6_conv2d_proj (Conv2D)   (None, 8, 11, 96)    36864       ['block_6_se_mult[0][0]']
#
#  block_6_bnorm_proj (BatchNorma  (None, 8, 11, 96)   384         ['block_6_conv2d_proj[0][0]']
#  lization)
#
#  block_6_stochdepth (Dropout)   (None, 8, 11, 96)    0           ['block_6_bnorm_proj[0][0]']
#
#  block_6_add (Add)              (None, 8, 11, 96)    0           ['block_5_bnorm_proj[0][0]',
#                                                                   'block_6_stochdepth[0][0]']
#
#  block_7_conv2d_expand (Conv2D)  (None, 8, 11, 384)  36864       ['block_6_add[0][0]']
#
#  block_7_bnorm_expand (BatchNor  (None, 8, 11, 384)  1536        ['block_7_conv2d_expand[0][0]']
#  malization)
#
#  block_7_act_expand (Lambda)    (None, 8, 11, 384)   0           ['block_7_bnorm_expand[0][0]']
#
#  block_7_dwconv2d (DepthwiseCon  (None, 8, 11, 384)  3456        ['block_7_act_expand[0][0]']
#  v2D)
#
#  block_7_bnorm (BatchNormalizat  (None, 8, 11, 384)  1536        ['block_7_dwconv2d[0][0]']
#  ion)
#
#  block_7_act (Lambda)           (None, 8, 11, 384)   0           ['block_7_bnorm[0][0]']
#
#  block_7_se_mean (Lambda)       (None, 1, 1, 384)    0           ['block_7_act[0][0]']
#
#  block_7_se_conv2d_s (Conv2D)   (None, 1, 1, 24)     9240        ['block_7_se_mean[0][0]']
#
#  block_7_se_act_s (Lambda)      (None, 1, 1, 24)     0           ['block_7_se_conv2d_s[0][0]']
#
#  block_7_se_conv2d_e (Conv2D)   (None, 1, 1, 384)    9600        ['block_7_se_act_s[0][0]']
#
#  block_7_se_act_e (Lambda)      (None, 1, 1, 384)    0           ['block_7_se_conv2d_e[0][0]']
#
#  block_7_se_mult (Multiply)     (None, 8, 11, 384)   0           ['block_7_se_act_e[0][0]',
#                                                                   'block_7_act[0][0]']
#
#  block_7_conv2d_proj (Conv2D)   (None, 8, 11, 96)    36864       ['block_7_se_mult[0][0]']
#
#  block_7_bnorm_proj (BatchNorma  (None, 8, 11, 96)   384         ['block_7_conv2d_proj[0][0]']
#  lization)
#
#  block_7_stochdepth (Dropout)   (None, 8, 11, 96)    0           ['block_7_bnorm_proj[0][0]']
#
#  block_7_add (Add)              (None, 8, 11, 96)    0           ['block_6_add[0][0]',
#                                                                   'block_7_stochdepth[0][0]']
#
#  block_8_conv2d_expand (Conv2D)  (None, 8, 11, 576)  55296       ['block_7_add[0][0]']
#
#  block_8_bnorm_expand (BatchNor  (None, 8, 11, 576)  2304        ['block_8_conv2d_expand[0][0]']
#  malization)
#
#  block_8_act_expand (Lambda)    (None, 8, 11, 576)   0           ['block_8_bnorm_expand[0][0]']
#
#  block_8_dwconv2d (DepthwiseCon  (None, 8, 11, 576)  5184        ['block_8_act_expand[0][0]']
#  v2D)
#
#  block_8_bnorm (BatchNormalizat  (None, 8, 11, 576)  2304        ['block_8_dwconv2d[0][0]']
#  ion)
#
#  block_8_act (Lambda)           (None, 8, 11, 576)   0           ['block_8_bnorm[0][0]']
#
#  block_8_se_mean (Lambda)       (None, 1, 1, 576)    0           ['block_8_act[0][0]']
#
#  block_8_se_conv2d_s (Conv2D)   (None, 1, 1, 24)     13848       ['block_8_se_mean[0][0]']
#
#  block_8_se_act_s (Lambda)      (None, 1, 1, 24)     0           ['block_8_se_conv2d_s[0][0]']
#
#  block_8_se_conv2d_e (Conv2D)   (None, 1, 1, 576)    14400       ['block_8_se_act_s[0][0]']
#
#  block_8_se_act_e (Lambda)      (None, 1, 1, 576)    0           ['block_8_se_conv2d_e[0][0]']
#
#  block_8_se_mult (Multiply)     (None, 8, 11, 576)   0           ['block_8_se_act_e[0][0]',
#                                                                   'block_8_act[0][0]']
#
#  block_8_conv2d_proj (Conv2D)   (None, 8, 11, 112)   64512       ['block_8_se_mult[0][0]']
#
#  block_8_bnorm_proj (BatchNorma  (None, 8, 11, 112)  448         ['block_8_conv2d_proj[0][0]']
#  lization)
#
#  block_9_conv2d_expand (Conv2D)  (None, 8, 11, 672)  75264       ['block_8_bnorm_proj[0][0]']
#
#  block_9_bnorm_expand (BatchNor  (None, 8, 11, 672)  2688        ['block_9_conv2d_expand[0][0]']
#  malization)
#
#  block_9_act_expand (Lambda)    (None, 8, 11, 672)   0           ['block_9_bnorm_expand[0][0]']
#
#  block_9_dwconv2d (DepthwiseCon  (None, 8, 11, 672)  6048        ['block_9_act_expand[0][0]']
#  v2D)
#
#  block_9_bnorm (BatchNormalizat  (None, 8, 11, 672)  2688        ['block_9_dwconv2d[0][0]']
#  ion)
#
#  block_9_act (Lambda)           (None, 8, 11, 672)   0           ['block_9_bnorm[0][0]']
#
#  block_9_se_mean (Lambda)       (None, 1, 1, 672)    0           ['block_9_act[0][0]']
#
#  block_9_se_conv2d_s (Conv2D)   (None, 1, 1, 28)     18844       ['block_9_se_mean[0][0]']
#
#  block_9_se_act_s (Lambda)      (None, 1, 1, 28)     0           ['block_9_se_conv2d_s[0][0]']
#
#  block_9_se_conv2d_e (Conv2D)   (None, 1, 1, 672)    19488       ['block_9_se_act_s[0][0]']
#
#  block_9_se_act_e (Lambda)      (None, 1, 1, 672)    0           ['block_9_se_conv2d_e[0][0]']
#
#  block_9_se_mult (Multiply)     (None, 8, 11, 672)   0           ['block_9_se_act_e[0][0]',
#                                                                   'block_9_act[0][0]']
#
#  block_9_conv2d_proj (Conv2D)   (None, 8, 11, 112)   75264       ['block_9_se_mult[0][0]']
#
#  block_9_bnorm_proj (BatchNorma  (None, 8, 11, 112)  448         ['block_9_conv2d_proj[0][0]']
#  lization)
#
#  block_9_stochdepth (Dropout)   (None, 8, 11, 112)   0           ['block_9_bnorm_proj[0][0]']
#
#  block_9_add (Add)              (None, 8, 11, 112)   0           ['block_8_bnorm_proj[0][0]',
#                                                                   'block_9_stochdepth[0][0]']
#
#  block_10_conv2d_expand (Conv2D  (None, 8, 11, 672)  75264       ['block_9_add[0][0]']
#  )
#
#  block_10_bnorm_expand (BatchNo  (None, 8, 11, 672)  2688        ['block_10_conv2d_expand[0][0]']
#  rmalization)
#
#  block_10_act_expand (Lambda)   (None, 8, 11, 672)   0           ['block_10_bnorm_expand[0][0]']
#
#  block_10_dwconv2d (DepthwiseCo  (None, 8, 11, 672)  6048        ['block_10_act_expand[0][0]']
#  nv2D)
#
#  block_10_bnorm (BatchNormaliza  (None, 8, 11, 672)  2688        ['block_10_dwconv2d[0][0]']
#  tion)
#
#  block_10_act (Lambda)          (None, 8, 11, 672)   0           ['block_10_bnorm[0][0]']
#
#  block_10_se_mean (Lambda)      (None, 1, 1, 672)    0           ['block_10_act[0][0]']
#
#  block_10_se_conv2d_s (Conv2D)  (None, 1, 1, 28)     18844       ['block_10_se_mean[0][0]']
#
#  block_10_se_act_s (Lambda)     (None, 1, 1, 28)     0           ['block_10_se_conv2d_s[0][0]']
#
#  block_10_se_conv2d_e (Conv2D)  (None, 1, 1, 672)    19488       ['block_10_se_act_s[0][0]']
#
#  block_10_se_act_e (Lambda)     (None, 1, 1, 672)    0           ['block_10_se_conv2d_e[0][0]']
#
#  block_10_se_mult (Multiply)    (None, 8, 11, 672)   0           ['block_10_se_act_e[0][0]',
#                                                                   'block_10_act[0][0]']
#
#  block_10_conv2d_proj (Conv2D)  (None, 8, 11, 112)   75264       ['block_10_se_mult[0][0]']
#
#  block_10_bnorm_proj (BatchNorm  (None, 8, 11, 112)  448         ['block_10_conv2d_proj[0][0]']
#  alization)
#
#  block_10_stochdepth (Dropout)  (None, 8, 11, 112)   0           ['block_10_bnorm_proj[0][0]']
#
#  block_10_add (Add)             (None, 8, 11, 112)   0           ['block_9_add[0][0]',
#                                                                   'block_10_stochdepth[0][0]']
#
#  block_11_conv2d_expand (Conv2D  (None, 8, 11, 672)  75264       ['block_10_add[0][0]']
#  )
#
#  block_11_bnorm_expand (BatchNo  (None, 8, 11, 672)  2688        ['block_11_conv2d_expand[0][0]']
#  rmalization)
#
#  block_11_act_expand (Lambda)   (None, 8, 11, 672)   0           ['block_11_bnorm_expand[0][0]']
#
#  block_11_dwconv2d (DepthwiseCo  (None, 8, 11, 672)  6048        ['block_11_act_expand[0][0]']
#  nv2D)
#
#  block_11_bnorm (BatchNormaliza  (None, 8, 11, 672)  2688        ['block_11_dwconv2d[0][0]']
#  tion)
#
#  block_11_act (Lambda)          (None, 8, 11, 672)   0           ['block_11_bnorm[0][0]']
#
#  block_11_se_mean (Lambda)      (None, 1, 1, 672)    0           ['block_11_act[0][0]']
#
#  block_11_se_conv2d_s (Conv2D)  (None, 1, 1, 28)     18844       ['block_11_se_mean[0][0]']
#
#  block_11_se_act_s (Lambda)     (None, 1, 1, 28)     0           ['block_11_se_conv2d_s[0][0]']
#
#  block_11_se_conv2d_e (Conv2D)  (None, 1, 1, 672)    19488       ['block_11_se_act_s[0][0]']
#
#  block_11_se_act_e (Lambda)     (None, 1, 1, 672)    0           ['block_11_se_conv2d_e[0][0]']
#
#  block_11_se_mult (Multiply)    (None, 8, 11, 672)   0           ['block_11_se_act_e[0][0]',
#                                                                   'block_11_act[0][0]']
#
#  block_11_conv2d_proj (Conv2D)  (None, 8, 11, 112)   75264       ['block_11_se_mult[0][0]']
#
#  block_11_bnorm_proj (BatchNorm  (None, 8, 11, 112)  448         ['block_11_conv2d_proj[0][0]']
#  alization)
#
#  block_11_stochdepth (Dropout)  (None, 8, 11, 112)   0           ['block_11_bnorm_proj[0][0]']
#
#  block_11_add (Add)             (None, 8, 11, 112)   0           ['block_10_add[0][0]',
#                                                                   'block_11_stochdepth[0][0]']
#
#  block_12_conv2d_expand (Conv2D  (None, 8, 11, 672)  75264       ['block_11_add[0][0]']
#  )
#
#  block_12_bnorm_expand (BatchNo  (None, 8, 11, 672)  2688        ['block_12_conv2d_expand[0][0]']
#  rmalization)
#
#  block_12_act_expand (Lambda)   (None, 8, 11, 672)   0           ['block_12_bnorm_expand[0][0]']
#
#  block_12_dwconv2d (DepthwiseCo  (None, 8, 11, 672)  6048        ['block_12_act_expand[0][0]']
#  nv2D)
#
#  block_12_bnorm (BatchNormaliza  (None, 8, 11, 672)  2688        ['block_12_dwconv2d[0][0]']
#  tion)
#
#  block_12_act (Lambda)          (None, 8, 11, 672)   0           ['block_12_bnorm[0][0]']
#
#  block_12_se_mean (Lambda)      (None, 1, 1, 672)    0           ['block_12_act[0][0]']
#
#  block_12_se_conv2d_s (Conv2D)  (None, 1, 1, 28)     18844       ['block_12_se_mean[0][0]']
#
#  block_12_se_act_s (Lambda)     (None, 1, 1, 28)     0           ['block_12_se_conv2d_s[0][0]']
#
#  block_12_se_conv2d_e (Conv2D)  (None, 1, 1, 672)    19488       ['block_12_se_act_s[0][0]']
#
#  block_12_se_act_e (Lambda)     (None, 1, 1, 672)    0           ['block_12_se_conv2d_e[0][0]']
#
#  block_12_se_mult (Multiply)    (None, 8, 11, 672)   0           ['block_12_se_act_e[0][0]',
#                                                                   'block_12_act[0][0]']
#
#  block_12_conv2d_proj (Conv2D)  (None, 8, 11, 112)   75264       ['block_12_se_mult[0][0]']
#
#  block_12_bnorm_proj (BatchNorm  (None, 8, 11, 112)  448         ['block_12_conv2d_proj[0][0]']
#  alization)
#
#  block_12_stochdepth (Dropout)  (None, 8, 11, 112)   0           ['block_12_bnorm_proj[0][0]']
#
#  block_12_add (Add)             (None, 8, 11, 112)   0           ['block_11_add[0][0]',
#                                                                   'block_12_stochdepth[0][0]']
#
#  block_13_conv2d_expand (Conv2D  (None, 8, 11, 672)  75264       ['block_12_add[0][0]']
#  )
#
#  block_13_bnorm_expand (BatchNo  (None, 8, 11, 672)  2688        ['block_13_conv2d_expand[0][0]']
#  rmalization)
#
#  block_13_act_expand (Lambda)   (None, 8, 11, 672)   0           ['block_13_bnorm_expand[0][0]']
#
#  block_13_dwconv2d (DepthwiseCo  (None, 4, 6, 672)   6048        ['block_13_act_expand[0][0]']
#  nv2D)
#
#  block_13_bnorm (BatchNormaliza  (None, 4, 6, 672)   2688        ['block_13_dwconv2d[0][0]']
#  tion)
#
#  block_13_act (Lambda)          (None, 4, 6, 672)    0           ['block_13_bnorm[0][0]']
#
#  block_13_se_mean (Lambda)      (None, 1, 1, 672)    0           ['block_13_act[0][0]']
#
#  block_13_se_conv2d_s (Conv2D)  (None, 1, 1, 28)     18844       ['block_13_se_mean[0][0]']
#
#  block_13_se_act_s (Lambda)     (None, 1, 1, 28)     0           ['block_13_se_conv2d_s[0][0]']
#
#  block_13_se_conv2d_e (Conv2D)  (None, 1, 1, 672)    19488       ['block_13_se_act_s[0][0]']
#
#  block_13_se_act_e (Lambda)     (None, 1, 1, 672)    0           ['block_13_se_conv2d_e[0][0]']
#
#  block_13_se_mult (Multiply)    (None, 4, 6, 672)    0           ['block_13_se_act_e[0][0]',
#                                                                   'block_13_act[0][0]']
#
#  block_13_conv2d_proj (Conv2D)  (None, 4, 6, 192)    129024      ['block_13_se_mult[0][0]']
#
#  block_13_bnorm_proj (BatchNorm  (None, 4, 6, 192)   768         ['block_13_conv2d_proj[0][0]']
#  alization)
#
#  block_14_conv2d_expand (Conv2D  (None, 4, 6, 1152)  221184      ['block_13_bnorm_proj[0][0]']
#  )
#
#  block_14_bnorm_expand (BatchNo  (None, 4, 6, 1152)  4608        ['block_14_conv2d_expand[0][0]']
#  rmalization)
#
#  block_14_act_expand (Lambda)   (None, 4, 6, 1152)   0           ['block_14_bnorm_expand[0][0]']
#
#  block_14_dwconv2d (DepthwiseCo  (None, 4, 6, 1152)  10368       ['block_14_act_expand[0][0]']
#  nv2D)
#
#  block_14_bnorm (BatchNormaliza  (None, 4, 6, 1152)  4608        ['block_14_dwconv2d[0][0]']
#  tion)
#
#  block_14_act (Lambda)          (None, 4, 6, 1152)   0           ['block_14_bnorm[0][0]']
#
#  block_14_se_mean (Lambda)      (None, 1, 1, 1152)   0           ['block_14_act[0][0]']
#
#  block_14_se_conv2d_s (Conv2D)  (None, 1, 1, 48)     55344       ['block_14_se_mean[0][0]']
#
#  block_14_se_act_s (Lambda)     (None, 1, 1, 48)     0           ['block_14_se_conv2d_s[0][0]']
#
#  block_14_se_conv2d_e (Conv2D)  (None, 1, 1, 1152)   56448       ['block_14_se_act_s[0][0]']
#
#  block_14_se_act_e (Lambda)     (None, 1, 1, 1152)   0           ['block_14_se_conv2d_e[0][0]']
#
#  block_14_se_mult (Multiply)    (None, 4, 6, 1152)   0           ['block_14_se_act_e[0][0]',
#                                                                   'block_14_act[0][0]']
#
#  block_14_conv2d_proj (Conv2D)  (None, 4, 6, 192)    221184      ['block_14_se_mult[0][0]']
#
#  block_14_bnorm_proj (BatchNorm  (None, 4, 6, 192)   768         ['block_14_conv2d_proj[0][0]']
#  alization)
#
#  block_14_stochdepth (Dropout)  (None, 4, 6, 192)    0           ['block_14_bnorm_proj[0][0]']
#
#  block_14_add (Add)             (None, 4, 6, 192)    0           ['block_13_bnorm_proj[0][0]',
#                                                                   'block_14_stochdepth[0][0]']
#
#  block_15_conv2d_expand (Conv2D  (None, 4, 6, 1152)  221184      ['block_14_add[0][0]']
#  )
#
#  block_15_bnorm_expand (BatchNo  (None, 4, 6, 1152)  4608        ['block_15_conv2d_expand[0][0]']
#  rmalization)
#
#  block_15_act_expand (Lambda)   (None, 4, 6, 1152)   0           ['block_15_bnorm_expand[0][0]']
#
#  block_15_dwconv2d (DepthwiseCo  (None, 4, 6, 1152)  10368       ['block_15_act_expand[0][0]']
#  nv2D)
#
#  block_15_bnorm (BatchNormaliza  (None, 4, 6, 1152)  4608        ['block_15_dwconv2d[0][0]']
#  tion)
#
#  block_15_act (Lambda)          (None, 4, 6, 1152)   0           ['block_15_bnorm[0][0]']
#
#  block_15_se_mean (Lambda)      (None, 1, 1, 1152)   0           ['block_15_act[0][0]']
#
#  block_15_se_conv2d_s (Conv2D)  (None, 1, 1, 48)     55344       ['block_15_se_mean[0][0]']
#
# ...
#  block_17_conv2d_proj (Conv2D)  (None, 4, 6, 192)    221184      ['block_17_se_mult[0][0]']
#
#  block_17_bnorm_proj (BatchNorm  (None, 4, 6, 192)   768         ['block_17_conv2d_proj[0][0]']
#  alization)
#
#  block_17_stochdepth (Dropout)  (None, 4, 6, 192)    0           ['block_17_bnorm_proj[0][0]']
#
#  block_17_add (Add)             (None, 4, 6, 192)    0           ['block_16_add[0][0]',
#                                                                   'block_17_stochdepth[0][0]']
#
#  block_18_conv2d_expand (Conv2D  (None, 4, 6, 1152)  221184      ['block_17_add[0][0]']
#  )
#
#  block_18_bnorm_expand (BatchNo  (None, 4, 6, 1152)  4608        ['block_18_conv2d_expand[0][0]']
#  rmalization)
#
#  block_18_act_expand (Lambda)   (None, 4, 6, 1152)   0           ['block_18_bnorm_expand[0][0]']
#
#  block_18_dwconv2d (DepthwiseCo  (None, 4, 6, 1152)  10368       ['block_18_act_expand[0][0]']
#  nv2D)
#
#  block_18_bnorm (BatchNormaliza  (None, 4, 6, 1152)  4608        ['block_18_dwconv2d[0][0]']
#  tion)
#
#  block_18_act (Lambda)          (None, 4, 6, 1152)   0           ['block_18_bnorm[0][0]']
#
#  block_18_se_mean (Lambda)      (None, 1, 1, 1152)   0           ['block_18_act[0][0]']
#
#  block_18_se_conv2d_s (Conv2D)  (None, 1, 1, 48)     55344       ['block_18_se_mean[0][0]']
#
#  block_18_se_act_s (Lambda)     (None, 1, 1, 48)     0           ['block_18_se_conv2d_s[0][0]']
#
#  block_18_se_conv2d_e (Conv2D)  (None, 1, 1, 1152)   56448       ['block_18_se_act_s[0][0]']
#
#  block_18_se_act_e (Lambda)     (None, 1, 1, 1152)   0           ['block_18_se_conv2d_e[0][0]']
#
#  block_18_se_mult (Multiply)    (None, 4, 6, 1152)   0           ['block_18_se_act_e[0][0]',
#                                                                   'block_18_act[0][0]']
#
#  block_18_conv2d_proj (Conv2D)  (None, 4, 6, 192)    221184      ['block_18_se_mult[0][0]']
#
#  block_18_bnorm_proj (BatchNorm  (None, 4, 6, 192)   768         ['block_18_conv2d_proj[0][0]']
#  alization)
#
#  block_18_stochdepth (Dropout)  (None, 4, 6, 192)    0           ['block_18_bnorm_proj[0][0]']
#
#  block_18_add (Add)             (None, 4, 6, 192)    0           ['block_17_add[0][0]',
#                                                                   'block_18_stochdepth[0][0]']
#
#  block_19_conv2d_expand (Conv2D  (None, 4, 6, 1152)  221184      ['block_18_add[0][0]']
#  )
#
#  block_19_bnorm_expand (BatchNo  (None, 4, 6, 1152)  4608        ['block_19_conv2d_expand[0][0]']
#  rmalization)
#
#  block_19_act_expand (Lambda)   (None, 4, 6, 1152)   0           ['block_19_bnorm_expand[0][0]']
#
#  block_19_dwconv2d (DepthwiseCo  (None, 4, 6, 1152)  10368       ['block_19_act_expand[0][0]']
#  nv2D)
#
#  block_19_bnorm (BatchNormaliza  (None, 4, 6, 1152)  4608        ['block_19_dwconv2d[0][0]']
#  tion)
#
#  block_19_act (Lambda)          (None, 4, 6, 1152)   0           ['block_19_bnorm[0][0]']
#
#  block_19_se_mean (Lambda)      (None, 1, 1, 1152)   0           ['block_19_act[0][0]']
#
#  block_19_se_conv2d_s (Conv2D)  (None, 1, 1, 48)     55344       ['block_19_se_mean[0][0]']
#
#  block_19_se_act_s (Lambda)     (None, 1, 1, 48)     0           ['block_19_se_conv2d_s[0][0]']
#
#  block_19_se_conv2d_e (Conv2D)  (None, 1, 1, 1152)   56448       ['block_19_se_act_s[0][0]']
#
#  block_19_se_act_e (Lambda)     (None, 1, 1, 1152)   0           ['block_19_se_conv2d_e[0][0]']
#
#  block_19_se_mult (Multiply)    (None, 4, 6, 1152)   0           ['block_19_se_act_e[0][0]',
#                                                                   'block_19_act[0][0]']
#
#  block_19_conv2d_proj (Conv2D)  (None, 4, 6, 192)    221184      ['block_19_se_mult[0][0]']
#
#  block_19_bnorm_proj (BatchNorm  (None, 4, 6, 192)   768         ['block_19_conv2d_proj[0][0]']
#  alization)
#
#  block_19_stochdepth (Dropout)  (None, 4, 6, 192)    0           ['block_19_bnorm_proj[0][0]']
#
#  block_19_add (Add)             (None, 4, 6, 192)    0           ['block_18_add[0][0]',
#                                                                   'block_19_stochdepth[0][0]']
#
#  block_20_conv2d_expand (Conv2D  (None, 4, 6, 1152)  221184      ['block_19_add[0][0]']
#  )
#
#  block_20_bnorm_expand (BatchNo  (None, 4, 6, 1152)  4608        ['block_20_conv2d_expand[0][0]']
#  rmalization)
#
#  block_20_act_expand (Lambda)   (None, 4, 6, 1152)   0           ['block_20_bnorm_expand[0][0]']
#
#  block_20_dwconv2d (DepthwiseCo  (None, 4, 6, 1152)  10368       ['block_20_act_expand[0][0]']
#  nv2D)
#
#  block_20_bnorm (BatchNormaliza  (None, 4, 6, 1152)  4608        ['block_20_dwconv2d[0][0]']
#  tion)
#
#  block_20_act (Lambda)          (None, 4, 6, 1152)   0           ['block_20_bnorm[0][0]']
#
#  block_20_se_mean (Lambda)      (None, 1, 1, 1152)   0           ['block_20_act[0][0]']
#
#  block_20_se_conv2d_s (Conv2D)  (None, 1, 1, 48)     55344       ['block_20_se_mean[0][0]']
#
#  block_20_se_act_s (Lambda)     (None, 1, 1, 48)     0           ['block_20_se_conv2d_s[0][0]']
#
#  block_20_se_conv2d_e (Conv2D)  (None, 1, 1, 1152)   56448       ['block_20_se_act_s[0][0]']
#
#  block_20_se_act_e (Lambda)     (None, 1, 1, 1152)   0           ['block_20_se_conv2d_e[0][0]']
#
#  block_20_se_mult (Multiply)    (None, 4, 6, 1152)   0           ['block_20_se_act_e[0][0]',
#                                                                   'block_20_act[0][0]']
#
#  block_20_conv2d_proj (Conv2D)  (None, 4, 6, 192)    221184      ['block_20_se_mult[0][0]']
#
#  block_20_bnorm_proj (BatchNorm  (None, 4, 6, 192)   768         ['block_20_conv2d_proj[0][0]']
#  alization)
#
#  block_20_stochdepth (Dropout)  (None, 4, 6, 192)    0           ['block_20_bnorm_proj[0][0]']
#
#  block_20_add (Add)             (None, 4, 6, 192)    0           ['block_19_add[0][0]',
#                                                                   'block_20_stochdepth[0][0]']
#
#  head_conv2d (Conv2D)           (None, 4, 6, 1280)   245760      ['block_20_add[0][0]']
#
#  head_bnorm (BatchNormalization  (None, 4, 6, 1280)  5120        ['head_conv2d[0][0]']
#  )
#
#  head_act (Lambda)              (None, 4, 6, 1280)   0           ['head_bnorm[0][0]']
#
#  head_gap (GlobalAveragePooling  (None, 1280)        0           ['head_act[0][0]']
#  2D)
#
#  head_dropout (Dropout)         (None, 1280)         0           ['head_gap[0][0]']
#
#  head_fc (Dense)                (None, 4)            5124        ['head_dropout[0][0]']
#
# ==================================================================================================
# Total params: 5,924,436
# Trainable params: 5,863,828
# Non-trainable params: 60,608
# __________________________________________________________________________________________________
# Epoch 1/12
# 280/280 [==============================] - 91s 158ms/step - loss: 1.9055 - accuracy: 0.3999 - val_loss: 1.2628 - val_accuracy: 0.4420
# Epoch 2/12
# 280/280 [==============================] - 40s 142ms/step - loss: 1.4197 - accuracy: 0.4618 - val_loss: 1.1711 - val_accuracy: 0.4491
# Epoch 3/12
# 280/280 [==============================] - 41s 146ms/step - loss: 1.2817 - accuracy: 0.5006 - val_loss: 1.3205 - val_accuracy: 0.4750
# Epoch 4/12
# 280/280 [==============================] - 40s 143ms/step - loss: 1.2639 - accuracy: 0.4980 - val_loss: 1.1331 - val_accuracy: 0.5036
# Epoch 5/12
# 280/280 [==============================] - 40s 144ms/step - loss: 1.3413 - accuracy: 0.5033 - val_loss: 1.2075 - val_accuracy: 0.4393
# Epoch 6/12
# 280/280 [==============================] - 40s 143ms/step - loss: 1.2671 - accuracy: 0.5057 - val_loss: 1.3648 - val_accuracy: 0.4772
# Epoch 7/12
# 280/280 [==============================] - 41s 145ms/step - loss: 1.1482 - accuracy: 0.5294 - val_loss: 1.1256 - val_accuracy: 0.4705
# Epoch 8/12
# 280/280 [==============================] - 40s 143ms/step - loss: 1.1317 - accuracy: 0.5475 - val_loss: 1.1308 - val_accuracy: 0.4661
# Epoch 9/12
# 280/280 [==============================] - 41s 148ms/step - loss: 1.0766 - accuracy: 0.5772 - val_loss: 1.1403 - val_accuracy: 0.5143
# Epoch 10/12
# 280/280 [==============================] - 40s 144ms/step - loss: 1.0306 - accuracy: 0.6037 - val_loss: 1.1378 - val_accuracy: 0.5071
# Epoch 11/12
# 280/280 [==============================] - 40s 142ms/step - loss: 1.0151 - accuracy: 0.6267 - val_loss: 1.1178 - val_accuracy: 0.5375
# Epoch 12/12
# 280/280 [==============================] - 40s 143ms/step - loss: 0.9785 - accuracy: 0.6442 - val_loss: 1.2790 - val_accuracy: 0.4978

# %%
from matplotlib import pyplot as plt
def get_class_string_from_index(index):
   for class_string, class_index in valid_generator.class_indices.items():
      if class_index == index:
         return class_string

x, y = next(valid_generator)
image = x[0, :, :, :]
true_index = np.argmax(y[0])
plt.imshow(image)
plt.axis('off')
plt.show()

# Expand the validation image to (1, 224, 224, 3) before predicting the label
prediction_scores = model.predict(np.expand_dims(image, axis=0))
predicted_index = np.argmax(prediction_scores)
print("True label: " + get_class_string_from_index(true_index))
print("Predicted label: " + get_class_string_from_index(predicted_index))
# Out:
# True label: Q1
# Predicted label: Q4

# %%
model.save(RESEARCH_WORK_PATH + "models/efficient_net_v2_vanilla_mel")
# Out:
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/BachelorResearch/models/efficient_net_v2_vanilla_mel/assets

# %%
# 学習状況のプロット関数の定義
def plot_history(history):
    # 分類精度の履歴をプロット
    plt.plot(history['accuracy'])
    plt.plot(history['val_accuracy'])
    plt.title('model accuracy')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.legend(['training', 'validation'], loc='lower right')
    plt.show()

    # 損失関数の履歴をプロット
    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    plt.title('model loss')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['training', 'validation'], loc='upper right')
    plt.show()

plot_history(hist)

# %% [markdown]
# # mel (defined handwrite-ly)
#
#
#
# ```
# Epoch 1/12
# 280/280 [==============================] - 59s 160ms/step - loss: 1.9180 - accuracy: 0.4148 - val_loss: 1.7711 - val_accuracy: 0.3888
# Epoch 2/12
# 280/280 [==============================] - 42s 148ms/step - loss: 1.4502 - accuracy: 0.4896 - val_loss: 1.2815 - val_accuracy: 0.4714
# Epoch 3/12
# 280/280 [==============================] - 42s 149ms/step - loss: 1.3166 - accuracy: 0.4904 - val_loss: 1.4803 - val_accuracy: 0.4723
# Epoch 4/12
# 280/280 [==============================] - 41s 145ms/step - loss: 1.2195 - accuracy: 0.5160 - val_loss: 1.1881 - val_accuracy: 0.4598
# Epoch 5/12
# 280/280 [==============================] - 41s 145ms/step - loss: 1.1661 - accuracy: 0.5393 - val_loss: 1.1590 - val_accuracy: 0.4853
# Epoch 6/12
# 280/280 [==============================] - 41s 146ms/step - loss: 1.0880 - accuracy: 0.5661 - val_loss: 1.1503 - val_accuracy: 0.5027
# Epoch 7/12
# 280/280 [==============================] - 41s 145ms/step - loss: 1.0500 - accuracy: 0.6023 - val_loss: 1.1970 - val_accuracy: 0.5089
# Epoch 8/12
# 280/280 [==============================] - 42s 149ms/step - loss: 1.0347 - accuracy: 0.6170 - val_loss: 1.1704 - val_accuracy: 0.5254
# Epoch 9/12
# 280/280 [==============================] - 41s 146ms/step - loss: 1.0023 - accuracy: 0.6391 - val_loss: 1.2295 - val_accuracy: 0.5353
# Epoch 10/12
# 280/280 [==============================] - 41s 145ms/step - loss: 0.9944 - accuracy: 0.6571 - val_loss: 1.2070 - val_accuracy: 0.5272
# Epoch 11/12
# 280/280 [==============================] - 41s 146ms/step - loss: 0.9970 - accuracy: 0.6401 - val_loss: 1.1846 - val_accuracy: 0.5018
# Epoch 12/12
# 280/280 [==============================] - 40s 143ms/step - loss: 0.9436 - accuracy: 0.6795 - val_loss: 1.1943 - val_accuracy: 0.5246
# ```
#
#
#
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # mel(librosa)
#
# ```
# Epoch 1/12
# 280/280 [==============================] - 91s 158ms/step - loss: 1.9055 - accuracy: 0.3999 - val_loss: 1.2628 - val_accuracy: 0.4420
# Epoch 2/12
# 280/280 [==============================] - 40s 142ms/step - loss: 1.4197 - accuracy: 0.4618 - val_loss: 1.1711 - val_accuracy: 0.4491
# Epoch 3/12
# 280/280 [==============================] - 41s 146ms/step - loss: 1.2817 - accuracy: 0.5006 - val_loss: 1.3205 - val_accuracy: 0.4750
# Epoch 4/12
# 280/280 [==============================] - 40s 143ms/step - loss: 1.2639 - accuracy: 0.4980 - val_loss: 1.1331 - val_accuracy: 0.5036
# Epoch 5/12
# 280/280 [==============================] - 40s 144ms/step - loss: 1.3413 - accuracy: 0.5033 - val_loss: 1.2075 - val_accuracy: 0.4393
# Epoch 6/12
# 280/280 [==============================] - 40s 143ms/step - loss: 1.2671 - accuracy: 0.5057 - val_loss: 1.3648 - val_accuracy: 0.4772
# Epoch 7/12
# 280/280 [==============================] - 41s 145ms/step - loss: 1.1482 - accuracy: 0.5294 - val_loss: 1.1256 - val_accuracy: 0.4705
# Epoch 8/12
# 280/280 [==============================] - 40s 143ms/step - loss: 1.1317 - accuracy: 0.5475 - val_loss: 1.1308 - val_accuracy: 0.4661
# Epoch 9/12
# 280/280 [==============================] - 41s 148ms/step - loss: 1.0766 - accuracy: 0.5772 - val_loss: 1.1403 - val_accuracy: 0.5143
# Epoch 10/12
# 280/280 [==============================] - 40s 144ms/step - loss: 1.0306 - accuracy: 0.6037 - val_loss: 1.1378 - val_accuracy: 0.5071
# Epoch 11/12
# 280/280 [==============================] - 40s 142ms/step - loss: 1.0151 - accuracy: 0.6267 - val_loss: 1.1178 - val_accuracy: 0.5375
# Epoch 12/12
# 280/280 [==============================] - 40s 143ms/step - loss: 0.9785 - accuracy: 0.6442 - val_loss: 1.2790 - val_accuracy: 0.4978
# ```
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
