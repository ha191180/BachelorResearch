# %%
from google.colab import drive
drive.mount('/content/drive')
RESEARCH_WORK_PATH = "/content/drive/My Drive/Colab Notebooks/BachelorResearch/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Initialize

# %%
#@title Import {display-mode: "form"}
import math
import torch
from torch import nn

# %% [markdown]
# # Model

# %%
#@title Swish {display-mode: "form"}
class Swish(nn.Module):
  def forward(self, x):
    return x * torch.sigmoid(x)

# %%
#@title FeatureEx1d {display-mode: "form"}
class FeatureEx1d(nn.Module):
  def __init__(self, input_size):
    super().__init__()
    self.layers = nn.Sequential(
        nn.linear(input_size, 256),
        nn.functional.relu(),
        nn.linear(256, 128),
        nn.functional.relu(),
        nn.linear(128, 64),
        nn.functional.relu()
    )

  def forward(self, x):
    return self.layers(x)

# %%
#@title SEblock {display-mode: "form"}
class SEblock(nn.Module):
  def __init__(self, ch_in, ch_sq):
    super().__init__()
    self.se = nn.Sequential(
        nn.AdaptiveAvgPool2d(1),
        nn.Conv2d(ch_in, ch_sq, 1),
        Swish(),
        nn.Conv2d(ch_sq, ch_in, 1),
    )
    self.se.apply(weight_init)

  def forward(self, x):
    return x * torch.sigmoid(self.se(x))

def weight_init(m):
  if isinstance(m, nn.Conv2d):
    nn.init.kaiming_normal_(m.weight)

  if isinstance(m, nn.Linear):
    nn.init.kaiming_uniform_(m.weight)
    nn.init.zeros_(m.bias)

# %%
#@title ConvBNFirst {display-mode: "form"}
class ConvBNFirst(nn.Module):
  def __init__(self, ch_in, ch_out, kernel_size=(3, 257), stride=(1, 257), padding=0, groups=1):
    super().__init__()
    self.layers=nn.Sequential(
        nn.Conv2d(ch_in, ch_out, kernel_size, stride, padding, groups=groups, bias=False),
        nn.BatchNorm2d(ch_out),
    )
    self.layers.apply(weight_init)

  def forward(self, x):
    return self.layers(x)

# %%
#@title ConvBN {display-mode: "form"}
class ConvBN(nn.Module):
  def __init__(self, ch_in, ch_out, kernel_size, stride=1, padding=0, groups=1):
    super().__init__()
    self.layers=nn.Sequential(
        nn.Conv2d(ch_in, ch_out, kernel_size, stride, padding, groups=groups, bias=False),
        nn.BatchNorm2d(ch_out),
    )
    self.layers.apply(weight_init)

  def forward(self, x):
    return self.layers(x)

# %%
#@title DropConnect {display-mode: "form"}
class DropConnect(nn.Module):
  def __init__(self, drop_rate):
    super().__init__()
    self.drop_rate=drop_rate

  def forward(self, x):
    if self.training:
      keep_rate=1.0-self.drop_rate
      r = torch.rand([x.size(0),1,1,1], dtype=x.dtype).to(x.device)
      r+=keep_rate
      mask=r.floor()
      return x.div(keep_rate)*mask
    else:
      return x

# %%
#@title BMConvBlock {display-mode: "form"}
class BMConvBlock(nn.Module):
  def __init__(self,ch_in,ch_out,expand_ratio,stride,kernel_size,reduction_ratio=4,drop_connect_rate=0.2):
    super().__init__()
    self.use_residual = (ch_in==ch_out) & (stride==1)
    ch_med = int(ch_in*expand_ratio)
    ch_sq  = max(1, ch_in//reduction_ratio)

    if expand_ratio != 1.0:
      layers = [ConvBN(ch_in, ch_med, 1), Swish()]
    else:
      layers = []
    
    layers.extend([ConvBN(ch_med, ch_med, kernel_size, stride=stride, padding=0, groups=ch_med),
                  Swish(),
                  SEblock(ch_med, ch_sq),
                  ConvBN(ch_med, ch_out, 1),
                  ])
    
    if self.use_residual:
      self.drop_connect = DropConnect(drop_connect_rate)

    self.layers = nn.Sequential(*layers)

  def forward(self, x):
    if self.use_residual:
      return x + self.drop_connect(self.layers(x))
    else:
      return self.layers(x)

# %%
#@title Flatten {display-mode: "form"}
class Flatten(nn.Module):
  def forward(self, x):
    return x.view(x.shape[0], -1)

# %%
#@title MultiModalNet {display-mode: "form"}
class MultiModalNet(nn.Module):
  def __init__(self,
               width_mult=2.0,
               depth_mult=1.0,
               resolution=None,
               dropout_rate=0.2,
               num_1d_features=10,
               num_classes=4,
               input_ch=3):
    super().__init__()
    '''
    # expand_ratio, channel, repeats, stride, kernel_size                   
    settings = [
        [1,  16, 1, 1, 3],  # MBConv1_3x3, SE, 112 -> 112                   
        [6,  24, 2, 2, 3],  # MBConv6_3x3, SE, 112 ->  56                   
        [6,  40, 2, 2, 5],  # MBConv6_5x5, SE,  56 ->  28                   
        [6,  80, 3, 2, 3],  # MBConv6_3x3, SE,  28 ->  14                   
        [6, 112, 3, 1, 5],  # MBConv6_5x5, SE,  14 ->  14                   
        [6, 192, 4, 2, 5],  # MBConv6_5x5, SE,  14 ->   7                   
        [6, 320, 1, 1, 3]   # MBConv6_3x3, SE,   7 ->   7]                  
    ]
    ch_out = int(math.ceil(32*width_mult))
    features = [nn.AdaptiveAvgPool2d(resolution)] if resolution else []
    features.extend([ConvBNFirst(input_ch, ch_out), Swish()])     # -> [32, 3, 3, 3]

    ch_in = ch_out
    for t, c, n, s, k in settings:
      ch_out = int(math.ceil(c*width_mult))
      repeats = int(math.ceil(n*depth_mult))
      for i in range(repeats):
        stride = s if i==0 else 1
        features.extend([BMConvBlock(ch_in, ch_out, t, stride, k)])
        ch_in = ch_out

    '''
    features = [BMConvBlock(input_ch, 32, expand_ratio=6, stride=(1,257), kernel_size=(1, 257))]
    features.extend([BMConvBlock(32, 32, expand_ratio=6, stride=(2,1), kernel_size=(5,1))])
    features.extend([BMConvBlock(32, 32, expand_ratio=6, stride=(2,1), kernel_size=(5,1))])
    features.extend([BMConvBlock(32, 32, expand_ratio=6, stride=(2,1), kernel_size=(5,1))])

    ch_last = int(math.ceil(1280*width_mult))
    features.extend([ConvBN(32, ch_last, 1), Swish()])

    self.features2d = nn.Sequential(*features)
    self.reshape = nn.Sequential(
        nn.AdaptiveAvgPool2d(1),
        Flatten(),
        nn.Dropout(dropout_rate),
        nn.Linear(ch_last, 128)
    )
    self.classifier = nn.Sequential(
        nn.Linear(128*2, 128),
        nn.ReLU(),
        nn.Linear(128, 64),
        nn.ReLU(),
        nn.Linear(64, num_classes),
        nn.Softmax(dim=1)
    )

    self.features1d = nn.Sequential(
        nn.Linear(num_1d_features, 256),
        nn.ReLU(),
        nn.Linear(256, 128),
        nn.ReLU(),
    )

  def forward(self, x):
    x1=self.features2d(x[1])
    x1=self.reshape(x1)
    x0=self.features1d(x[0])
    x = torch.cat((x0,x1), dim=1)
    x=self.classifier(x)

    return x

# %% [markdown]
# # Model (Instance)

# %%
from torch import optim

num_1d_features = 26
model     = MultiModalNet(input_ch=1, num_classes=4, num_1d_features=num_1d_features).to('cuda')
optimizer = optim.SGD(model.parameters(),lr=0.05)
criterion = nn.CrossEntropyLoss()

# %%
import soundfile as sf
import librosa
import pathlib
import numpy as np
from matplotlib import pyplot as plt
from tensorflow import keras 
import os
import cv2
import pickle
import torch

model_path = '/content/drive/MyDrive/Colab Notebooks/BachelorResearch/models/multimodal_5s_0.5shift_200epoch_fixed_kernel_2.pth'
model.load_state_dict(torch.load(model_path))
scaler = pickle.load(open(RESEARCH_WORK_PATH + "/models/1d_scaler_5s_0.5shift.pickle", "rb"))
model.eval()
# Out:
# MultiModalNet(
#   (features2d): Sequential(
#     (0): BMConvBlock(
#       (layers): Sequential(
#         (0): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(1, 6, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Swish()
#         (2): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(6, 6, kernel_size=(1, 257), stride=(1, 257), groups=6, bias=False)
#             (1): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (3): Swish()
#         (4): SEblock(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(6, 1, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(1, 6, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (5): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(6, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (1): BMConvBlock(
#       (layers): Sequential(
#         (0): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Swish()
#         (2): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(192, 192, kernel_size=(5, 1), stride=(2, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (3): Swish()
#         (4): SEblock(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (5): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (2): BMConvBlock(
#       (layers): Sequential(
#         (0): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Swish()
#         (2): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(192, 192, kernel_size=(5, 1), stride=(2, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (3): Swish()
#         (4): SEblock(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (5): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (3): BMConvBlock(
#       (layers): Sequential(
#         (0): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Swish()
#         (2): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(192, 192, kernel_size=(5, 1), stride=(2, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (3): Swish()
#         (4): SEblock(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (5): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (4): ConvBN(
#       (layers): Sequential(
#         (0): Conv2d(32, 2560, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(2560, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Swish()
#   )
#   (reshape): Sequential(
#     (0): AdaptiveAvgPool2d(output_size=1)
#     (1): Flatten()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=2560, out_features=128, bias=True)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=256, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=4, bias=True)
#     (5): Softmax(dim=1)
#   )
#   (features1d): Sequential(
#     (0): Linear(in_features=26, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=128, bias=True)
#     (3): ReLU()
#   )
# )

# %% [markdown]
# # Prediction

# %%
def min_max(x, axis=None): # do min_max normalization ?->https://atmarkit.itmedia.co.jp/ait/articles/2110/07/news027.html
    min = 0
    max = 159.42822
    # max = 137.74599
    x = np.abs(x)
    result = (x-min)/(max-min)
    return result


def path_to_audiofiles(dir_folder):
    list_of_audio = []
    for file in os.listdir(dir_folder):
        if file.endswith(".wav"):
            directory = "%s%s" % (dir_folder, file)
            list_of_audio.append(directory)
    return list_of_audio

RESEARCH_WORK_PATH = "/content/drive/My Drive/Colab Notebooks/BachelorResearch/"
unknown = RESEARCH_WORK_PATH + "MER_audio_taffc_dataset_wav/renamed/unknown/"

# %%
rmss = [[], []]

for audio_path in (path_to_audiofiles(unknown)):
  true_index = int(pathlib.Path(audio_path).stem[1])-1
  print("True: Q" +  str(true_index+1))
  data, sr = librosa.load(audio_path) 
  broken_flag = False

  sum = torch.zeros(4, device='cuda')
  for i in range(46):
    start = sr//2*i
    stop  = 5*sr + sr//2*i

    # STFT
    n_fft=512
    hop_length=256
    
    y = data[start:stop]

    x = []
    try:
      stft = np.abs(librosa.stft(y, n_fft=n_fft, hop_length=hop_length))
    except ValueError :
      # print("[PASS] No data in", audio_path)
      broken_flag = True
      continue

    # Normalization
    stft = min_max(stft)

    # Data Transform
    stft = np.expand_dims(stft, axis=2)
    stft = np.expand_dims(stft, axis=0) # (Batch, Height, Width, Color)
    stft = torch.from_numpy(stft.astype(np.float32)).clone()
    stft = stft.permute(0,3,2,1)
    stft = stft.to('cuda')

    

    # np.set_printoptions(suppress=True)
    # print(input.shape)
    # print(type(input))
    # print(input[0,:,:,0])
    # print(input[0,:,:,1])
    # print(input[0,:,:,2])
    try: 
      chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
      rmse = librosa.feature.rms(y=y) # librosaのバージョンが0.7.0以上の場合はこちらを実行
      spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
      spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
      rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
      zcr = librosa.feature.zero_crossing_rate(y)
      mfcc = librosa.feature.mfcc(y=y, sr=sr)
      r = [np.mean(chroma_stft), np.mean(rmse), np.mean(spec_cent), np.mean(spec_bw), np.mean(rolloff), np.mean(zcr)]
      for e in mfcc:
        r.append(np.mean(e))
    except ValueError:
      # print("[PASS] No data in", audio_path)
      broken_flag = True
      continue

    r = np.array(r, dtype=float)
    r = np.expand_dims(r,0)
    r = scaler.transform(r)
    r = torch.from_numpy(r).float()
    r = r.to('cuda')
    
    x.append(r)
    x.append(stft)


    # Predict
    try:
      scores = model(x)
    except Exception:
      # print("[PASS] Not enough:", audio_path)
      scores = torch.zeros(1,4)
      broken_flag = True
      continue
    if scores[0][true_index] < 0.5:
      print("Incorrect!")
      rmss[0].append(r)
    else:
      rmss[1].append(r)
    print("\tSegment Info:")
    print("\tSuggest:", [round(i.item(),2) for i in scores[0]])
    print("\tRMS:", np.mean(rmse))

    # print(scores)

    # Get sum
    sum = sum + scores
  if broken_flag:
    print(pathlib.Path(audio_path).stem, "seems broken. len:", round(len(data)/sr,4) ,"sec")

  p = int(torch.argmax(sum, 1))
  print("Pred: Q" +  str(p+1))

print()
# Out:
# True: Q1
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.05889935
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.066711366
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.07348628
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.078559436
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.07947299
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.08055506
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.08064157
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.081192866
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.08311576
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.083050095
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.08822213
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.08695172
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.084762774
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.08192777
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.07873486
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.07525831
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.07472123
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.0719519
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.06757165
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.064066306
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.054995727
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.05541234
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.053710658
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.052716784
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.05401788
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.056571882
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.057166472
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.058860097
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.057627298
# 	Segment Info:
# 	Suggest: [0.99, 0.0, 0.01, 0.0]
# 	RMS: 0.059328213
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.05987825
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.061723556
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.06418512
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.06597377
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.066442065
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.06522603
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.06635953
# 	Segment Info:
# 	Suggest: [0.99, 0.0, 0.01, 0.0]
# 	RMS: 0.06905843
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.07264367
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.07526668
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.07567925
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.071084656
# 	Segment Info:
# 	Suggest: [0.99, 0.0, 0.01, 0.0]
# 	RMS: 0.07015055
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.06953172
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.068650894
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.07011472
# Pred: Q1
# True: Q1
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.06134522
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.06563555
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.06532088
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.06507394
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.06465251
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.067076474
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.069362134
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.072178975
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.070623726
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.06669846
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.061615687
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.060609933
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.06224681
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.06051039
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.06107676
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.07, 0.93]
# 	RMS: 0.06054278
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.051809125
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.035710733
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.025570462
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.018132247
# Q1.MT0013914319 seems broken. len: 10.08 sec
# Pred: Q4
# True: Q1
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1763
#   n_fft, y.shape[-1]
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=512 is too small for input signal of length=0
#   n_fft, y.shape[-1]
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.15611817
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.1769193
# 	Segment Info:
# 	Suggest: [0.78, 0.22, 0.0, 0.0]
# 	RMS: 0.19749075
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19873849
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19918057
# 	Segment Info:
# 	Suggest: [0.89, 0.11, 0.0, 0.0]
# 	RMS: 0.20917656
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.21270888
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.20566662
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19499962
# 	Segment Info:
# 	Suggest: [0.82, 0.18, 0.0, 0.0]
# 	RMS: 0.20128126
# 	Segment Info:
# 	Suggest: [0.99, 0.01, 0.0, 0.0]
# 	RMS: 0.20680802
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.20873909
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19463998
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19281395
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.20581354
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.20953086
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.01, 0.99, 0.0, 0.0]
# 	RMS: 0.20206958
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19290797
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.20051302
# 	Segment Info:
# 	Suggest: [0.99, 0.01, 0.0, 0.0]
# 	RMS: 0.20631348
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.20736605
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19952728
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.20526446
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.22069953
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.01, 0.99, 0.0, 0.0]
# 	RMS: 0.21978325
# 	Segment Info:
# 	Suggest: [0.9, 0.1, 0.0, 0.0]
# 	RMS: 0.21003444
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.2113077
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.22005142
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.2252741
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.22775717
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.14, 0.86, 0.0, 0.0]
# 	RMS: 0.22940229
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.24089426
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.2577969
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.26551723
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.27003187
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.28141907
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.28376594
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.2915253
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.28264394
# 	Segment Info:
# 	Suggest: [0.99, 0.01, 0.0, 0.0]
# 	RMS: 0.27000195
# 	Segment Info:
# 	Suggest: [0.97, 0.03, 0.0, 0.0]
# 	RMS: 0.2590369
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.25959933
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.24851878
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.22696635
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.21337566
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.20271814
# Pred: Q1
# True: Q1
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.02, 0.0, 0.98, 0.0]
# 	RMS: 0.10867228
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.03, 0.0, 0.97, 0.0]
# 	RMS: 0.11822471
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.12884527
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.01, 0.0, 0.99, 0.0]
# 	RMS: 0.12685432
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.12536055
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.12731229
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.1230174
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.42, 0.0, 0.58, 0.0]
# 	RMS: 0.11945315
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.12487487
# 	Segment Info:
# 	Suggest: [0.99, 0.0, 0.01, 0.0]
# 	RMS: 0.1199132
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.02, 0.0, 0.98, 0.0]
# 	RMS: 0.1222298
# 	Segment Info:
# 	Suggest: [0.99, 0.0, 0.01, 0.0]
# 	RMS: 0.12655365
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.46, 0.0, 0.54, 0.0]
# 	RMS: 0.12996988
# 	Segment Info:
# 	Suggest: [0.97, 0.0, 0.03, 0.0]
# 	RMS: 0.13102831
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.13414405
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.13021542
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.12951279
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.14041977
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.1432638
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.14952394
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.15061788
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.15070848
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.14456639
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.14587605
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.02, 0.0, 0.98, 0.0]
# 	RMS: 0.15061174
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.15491712
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.01, 0.0, 0.99, 0.0]
# 	RMS: 0.15769175
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.15287012
# 	Segment Info:
# 	Suggest: [0.97, 0.0, 0.03, 0.0]
# 	RMS: 0.1472593
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.1439162
# 	Segment Info:
# 	Suggest: [0.88, 0.0, 0.12, 0.0]
# 	RMS: 0.14252435
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.14617111
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.1446366
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.15070166
# 	Segment Info:
# 	Suggest: [0.88, 0.0, 0.12, 0.0]
# 	RMS: 0.15000772
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.14467502
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.01, 0.0, 0.99, 0.0]
# 	RMS: 0.14353198
# 	Segment Info:
# 	Suggest: [0.99, 0.0, 0.01, 0.0]
# 	RMS: 0.1394201
# 	Segment Info:
# 	Suggest: [0.99, 0.0, 0.01, 0.0]
# 	RMS: 0.13812645
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.13393939
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.35, 0.0, 0.65, 0.0]
# 	RMS: 0.14266455
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.14287761
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.17, 0.0, 0.83, 0.0]
# 	RMS: 0.14946909
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.14687365
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.14999822
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.1530131
# Pred: Q1
# True: Q1
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.16644709
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.1954589
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.21922524
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.23599377
# 	Segment Info:
# 	Suggest: [0.98, 0.02, 0.0, 0.0]
# 	RMS: 0.25427955
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.12, 0.88, 0.0, 0.0]
# 	RMS: 0.25925216
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.26406378
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.12, 0.88, 0.0, 0.0]
# 	RMS: 0.268969
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.2658689
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.26777434
# 	Segment Info:
# 	Suggest: [0.98, 0.02, 0.0, 0.0]
# 	RMS: 0.26908413
# 	Segment Info:
# 	Suggest: [0.98, 0.02, 0.0, 0.0]
# 	RMS: 0.26579434
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.26442748
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.26992097
# 	Segment Info:
# 	Suggest: [0.99, 0.01, 0.0, 0.0]
# 	RMS: 0.27817962
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.38, 0.62, 0.0, 0.0]
# 	RMS: 0.283714
# 	Segment Info:
# 	Suggest: [0.99, 0.01, 0.0, 0.0]
# 	RMS: 0.2813602
# 	Segment Info:
# 	Suggest: [0.59, 0.04, 0.0, 0.37]
# 	RMS: 0.27651525
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.2781068
# 	Segment Info:
# 	Suggest: [0.93, 0.07, 0.0, 0.0]
# 	RMS: 0.2827635
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.2798501
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.2735044
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.27405185
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.27263328
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.26654455
# 	Segment Info:
# 	Suggest: [0.96, 0.01, 0.0, 0.02]
# 	RMS: 0.27120766
# 	Segment Info:
# 	Suggest: [0.99, 0.01, 0.0, 0.0]
# 	RMS: 0.27720687
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.28023452
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.16, 0.66, 0.0, 0.18]
# 	RMS: 0.28191358
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.16, 0.0, 0.84]
# 	RMS: 0.28451407
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.2847742
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.29139102
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.28509843
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.32, 0.0, 0.0, 0.68]
# 	RMS: 0.28580412
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.29595017
# 	Segment Info:
# 	Suggest: [0.53, 0.0, 0.0, 0.47]
# 	RMS: 0.30163136
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.3005055
# 	Segment Info:
# 	Suggest: [0.99, 0.0, 0.0, 0.01]
# 	RMS: 0.29897773
# 	Segment Info:
# 	Suggest: [0.84, 0.0, 0.0, 0.16]
# 	RMS: 0.28880692
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.289197
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.28864086
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.02, 0.0, 0.0, 0.98]
# 	RMS: 0.28771767
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.29337093
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.2800113
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.2717107
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.25424427
# Pred: Q1
# True: Q1
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.12670766
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.02, 0.98, 0.0, 0.0]
# 	RMS: 0.13231783
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.24, 0.74, 0.02, 0.0]
# 	RMS: 0.13189289
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.49, 0.51, 0.0, 0.0]
# 	RMS: 0.13132957
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.13215256
# 	Segment Info:
# 	Suggest: [0.69, 0.31, 0.0, 0.0]
# 	RMS: 0.12936977
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.12730007
# 	Segment Info:
# 	Suggest: [0.68, 0.32, 0.0, 0.0]
# 	RMS: 0.12551247
# 	Segment Info:
# 	Suggest: [0.98, 0.02, 0.0, 0.0]
# 	RMS: 0.13044709
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.13184702
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.13008015
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.1336771
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.1358412
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.13877992
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.14317547
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.14820175
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.15266237
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.15952529
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.15345748
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.1498584
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.15162903
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.15123583
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.14951868
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.14708458
# 	Segment Info:
# 	Suggest: [0.95, 0.05, 0.0, 0.0]
# 	RMS: 0.14232376
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.41, 0.59, 0.0, 0.0]
# 	RMS: 0.13925384
# 	Segment Info:
# 	Suggest: [0.95, 0.05, 0.0, 0.0]
# 	RMS: 0.13426992
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.03, 0.97, 0.0, 0.0]
# 	RMS: 0.1254096
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.03, 0.97, 0.0, 0.0]
# 	RMS: 0.12758243
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.98, 0.0, 0.02]
# 	RMS: 0.1292794
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.12559192
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.12475608
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.12629421
# 	Segment Info:
# 	Suggest: [0.91, 0.09, 0.0, 0.0]
# 	RMS: 0.12878938
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.04, 0.96, 0.0, 0.0]
# 	RMS: 0.12938511
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.12559134
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.12692524
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.12901118
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.12807837
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.12947883
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.97, 0.0, 0.03]
# 	RMS: 0.13038538
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.13466904
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.13519877
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.13713135
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.13762015
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.01, 0.99, 0.0, 0.0]
# 	RMS: 0.14111312
# Pred: Q1
# True: Q1
# 	Segment Info:
# 	Suggest: [0.98, 0.0, 0.0, 0.02]
# 	RMS: 0.030325709
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.0382856
# 	Segment Info:
# 	Suggest: [0.99, 0.0, 0.0, 0.01]
# 	RMS: 0.044047505
# 	Segment Info:
# 	Suggest: [0.98, 0.0, 0.01, 0.01]
# 	RMS: 0.049927086
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.49, 0.0, 0.51, 0.0]
# 	RMS: 0.054484006
# 	Segment Info:
# 	Suggest: [0.99, 0.0, 0.01, 0.0]
# 	RMS: 0.058747053
# 	Segment Info:
# 	Suggest: [0.92, 0.0, 0.07, 0.0]
# 	RMS: 0.066618174
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.15, 0.0, 0.85, 0.0]
# 	RMS: 0.07324237
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.07, 0.0, 0.93, 0.0]
# 	RMS: 0.07557681
# 	Segment Info:
# 	Suggest: [0.94, 0.0, 0.06, 0.0]
# 	RMS: 0.07648154
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.074766845
# 	Segment Info:
# 	Suggest: [0.99, 0.0, 0.01, 0.0]
# 	RMS: 0.071544506
# 	Segment Info:
# 	Suggest: [0.99, 0.0, 0.01, 0.0]
# 	RMS: 0.07158799
# 	Segment Info:
# 	Suggest: [0.84, 0.0, 0.16, 0.0]
# 	RMS: 0.07180782
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.06818605
# 	Segment Info:
# 	Suggest: [0.95, 0.0, 0.05, 0.0]
# 	RMS: 0.06676691
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.06102412
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.05794644
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.057483252
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.06, 0.0, 0.01, 0.93]
# 	RMS: 0.05881285
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.057685684
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.056446142
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.05407848
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.050903816
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.052943572
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.0523571
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.054059356
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.053710382
# 	Segment Info:
# 	Suggest: [0.9, 0.0, 0.0, 0.1]
# 	RMS: 0.05381834
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.3, 0.0, 0.0, 0.7]
# 	RMS: 0.052798826
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.053226657
# 	Segment Info:
# 	Suggest: [0.91, 0.0, 0.0, 0.09]
# 	RMS: 0.05687875
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.059694864
# 	Segment Info:
# 	Suggest: [0.96, 0.0, 0.0, 0.04]
# 	RMS: 0.059047744
# 	Segment Info:
# 	Suggest: [0.99, 0.0, 0.0, 0.01]
# 	RMS: 0.05675308
# 	Segment Info:
# 	Suggest: [0.63, 0.0, 0.0, 0.37]
# 	RMS: 0.057971343
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.02, 0.0, 0.0, 0.98]
# 	RMS: 0.05802944
# 	Segment Info:
# 	Suggest: [0.97, 0.0, 0.0, 0.03]
# 	RMS: 0.05745706
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.05637004
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.056215093
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.05554264
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.053517625
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.051396996
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.049992695
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.05103536
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.052055027
# Pred: Q1
# True: Q1
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.13848184
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.16042928
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.18389085
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19903375
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.21644726
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.228396
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.23048516
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.22309226
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.22036666
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.21770191
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.22058868
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.22250655
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.22240648
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.2251671
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.22584817
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.22116868
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.22792654
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.24193728
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.2517905
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.24892789
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.23995925
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.24075173
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.23605092
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.23493479
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.22940265
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.23009796
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.2324871
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.03, 0.97, 0.0, 0.0]
# 	RMS: 0.23079522
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.2241131
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.2274661
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.23115565
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.22567432
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.22665654
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.21804427
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.22348414
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.22144975
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.21672039
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.21221627
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.21193543
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.20879173
# 	Segment Info:
# 	Suggest: [0.9, 0.0, 0.0, 0.1]
# 	RMS: 0.20569791
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.02, 0.0, 0.0, 0.98]
# 	RMS: 0.20565623
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.13, 0.0, 0.0, 0.87]
# 	RMS: 0.19913729
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.20697194
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.08, 0.0, 0.0, 0.91]
# 	RMS: 0.19226353
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.19035596
# Pred: Q1
# True: Q1
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.15250394
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.14, 0.65, 0.0, 0.21]
# 	RMS: 0.17606208
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.99, 0.0, 0.01]
# 	RMS: 0.18929623
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.20174287
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.20309341
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19626401
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.20043486
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19063346
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.18334156
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.1869255
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.18194745
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.17665125
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.17722613
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.16946267
# 	Segment Info:
# 	Suggest: [0.99, 0.0, 0.0, 0.0]
# 	RMS: 0.16542025
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.16548108
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.15452445
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.16191168
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.17113534
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.17125146
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.17670822
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.17663038
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.16707753
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.17282857
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.18291964
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19321579
# 	Segment Info:
# 	Suggest: [0.97, 0.0, 0.0, 0.03]
# 	RMS: 0.20059603
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19804499
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19147491
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.18923503
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19012596
# 	Segment Info:
# 	Suggest: [0.8, 0.0, 0.0, 0.2]
# 	RMS: 0.18786539
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.1970869
# 	Segment Info:
# 	Suggest: [0.87, 0.0, 0.0, 0.13]
# 	RMS: 0.19528724
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.18514067
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.1845094
# 	Segment Info:
# 	Suggest: [0.86, 0.1, 0.0, 0.03]
# 	RMS: 0.18274166
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19406079
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19589694
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19418451
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.20056492
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.2075571
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.20375647
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.21063006
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.2149785
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.20977987
# Pred: Q1
# True: Q1
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.98, 0.0, 0.02]
# 	RMS: 0.08130454
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.09145903
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.1008707
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.111684464
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.16, 0.84, 0.0, 0.0]
# 	RMS: 0.11861891
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.11939105
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.12297231
# 	Segment Info:
# 	Suggest: [0.7, 0.3, 0.0, 0.0]
# 	RMS: 0.12627302
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.98, 0.0, 0.01]
# 	RMS: 0.12921692
# 	Segment Info:
# 	Suggest: [0.93, 0.07, 0.0, 0.0]
# 	RMS: 0.1322612
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.1357307
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.13467243
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.13106672
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.124927394
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.11870623
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.11744137
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.112777226
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.1101203
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.10638922
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.10256032
# 	Segment Info:
# 	Suggest: [0.92, 0.0, 0.0, 0.08]
# 	RMS: 0.1014435
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.07, 0.2, 0.0, 0.73]
# 	RMS: 0.10346101
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.06, 0.32, 0.0, 0.61]
# 	RMS: 0.10446331
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.10638433
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.11133503
# 	Segment Info:
# 	Suggest: [0.72, 0.27, 0.0, 0.02]
# 	RMS: 0.11356391
# 	Segment Info:
# 	Suggest: [0.75, 0.25, 0.0, 0.0]
# 	RMS: 0.11857056
# 	Segment Info:
# 	Suggest: [0.95, 0.05, 0.0, 0.0]
# 	RMS: 0.12404818
# 	Segment Info:
# 	Suggest: [0.89, 0.11, 0.0, 0.0]
# 	RMS: 0.12634853
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.13192767
# 	Segment Info:
# 	Suggest: [0.93, 0.07, 0.0, 0.0]
# 	RMS: 0.13540024
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.12, 0.88, 0.0, 0.0]
# 	RMS: 0.13321449
# 	Segment Info:
# 	Suggest: [0.58, 0.42, 0.0, 0.0]
# 	RMS: 0.13257983
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.13153142
# 	Segment Info:
# 	Suggest: [0.99, 0.01, 0.0, 0.0]
# 	RMS: 0.12623613
# 	Segment Info:
# 	Suggest: [0.95, 0.05, 0.0, 0.0]
# 	RMS: 0.12228914
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.117516994
# 	Segment Info:
# 	Suggest: [0.99, 0.01, 0.0, 0.0]
# 	RMS: 0.11103354
# 	Segment Info:
# 	Suggest: [0.87, 0.13, 0.0, 0.0]
# 	RMS: 0.10796482
# 	Segment Info:
# 	Suggest: [0.94, 0.06, 0.0, 0.0]
# 	RMS: 0.105015665
# 	Segment Info:
# 	Suggest: [0.99, 0.01, 0.0, 0.0]
# 	RMS: 0.09935946
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.10049686
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.10175031
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.08, 0.92, 0.0, 0.0]
# 	RMS: 0.10076782
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.099902384
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.09696897
# Pred: Q1
# True: Q1
# 	Segment Info:
# 	Suggest: [0.99, 0.0, 0.01, 0.0]
# 	RMS: 0.086707026
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.09390954
# 	Segment Info:
# 	Suggest: [0.51, 0.0, 0.49, 0.0]
# 	RMS: 0.09862269
# 	Segment Info:
# 	Suggest: [0.93, 0.0, 0.07, 0.0]
# 	RMS: 0.09738106
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.09908796
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.09603625
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.09288009
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.090420485
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.09244232
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.093001895
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.09614223
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.09680072
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.10185356
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.10203363
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.05, 0.95, 0.0, 0.0]
# 	RMS: 0.09428343
# 	Segment Info:
# 	Suggest: [0.95, 0.04, 0.0, 0.0]
# 	RMS: 0.095311336
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.09352188
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.09492326
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.34, 0.66, 0.0, 0.0]
# 	RMS: 0.09564979
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.09351211
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.01, 0.99, 0.0, 0.0]
# 	RMS: 0.088074416
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.17, 0.83, 0.0, 0.0]
# 	RMS: 0.085025445
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.2, 0.8, 0.0, 0.0]
# 	RMS: 0.07723101
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.07809493
# 	Segment Info:
# 	Suggest: [0.8, 0.2, 0.0, 0.0]
# 	RMS: 0.082747586
# 	Segment Info:
# 	Suggest: [0.85, 0.15, 0.0, 0.0]
# 	RMS: 0.08216063
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.08291978
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.08584404
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.08632812
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.09303923
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.09702443
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.02, 0.0, 0.98, 0.0]
# 	RMS: 0.09779685
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.01, 0.0, 0.99, 0.0]
# 	RMS: 0.100923285
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.101108044
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.09926472
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.10067035
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.0956683
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.09452211
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.093552195
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.08618216
# 	Segment Info:
# 	Suggest: [0.72, 0.28, 0.0, 0.0]
# 	RMS: 0.08271002
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.21, 0.79, 0.0, 0.0]
# 	RMS: 0.080333725
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.074305326
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.07460142
# 	Segment Info:
# 	Suggest: [0.71, 0.29, 0.0, 0.0]
# 	RMS: 0.07312202
# 	Segment Info:
# 	Suggest: [0.79, 0.21, 0.0, 0.0]
# 	RMS: 0.07038305
# Pred: Q1
# True: Q1
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.14593029
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.04, 0.94, 0.0, 0.02]
# 	RMS: 0.1560868
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.16615203
# 	Segment Info:
# 	Suggest: [0.99, 0.01, 0.0, 0.0]
# 	RMS: 0.17951873
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.18494278
# 	Segment Info:
# 	Suggest: [0.98, 0.02, 0.0, 0.0]
# 	RMS: 0.17861564
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.18491077
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.22, 0.78, 0.0, 0.0]
# 	RMS: 0.18756893
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19405167
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19139773
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19932853
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.1, 0.82, 0.03, 0.05]
# 	RMS: 0.20826127
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.99, 0.0]
# 	RMS: 0.20058271
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.20071886
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19706383
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19197263
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.18597525
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.18794113
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.18897012
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.18143502
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.18240699
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.17928626
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.18197109
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.17485212
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.18191458
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19159466
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.18475586
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.18299304
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.18182224
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.18132849
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.17274798
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.34, 0.66, 0.0, 0.0]
# 	RMS: 0.1841524
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.1940869
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19841206
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.02, 0.12, 0.0, 0.86]
# 	RMS: 0.19757557
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.42, 0.58, 0.0, 0.0]
# 	RMS: 0.19568193
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.19863586
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.1899002
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.27, 0.73, 0.0, 0.0]
# 	RMS: 0.19998509
# 	Segment Info:
# 	Suggest: [0.99, 0.01, 0.0, 0.0]
# 	RMS: 0.2034304
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.20454448
# 	Segment Info:
# 	Suggest: [0.99, 0.01, 0.0, 0.0]
# 	RMS: 0.20257734
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.29, 0.71, 0.0, 0.0]
# 	RMS: 0.1941096
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.1, 0.9, 0.0, 0.0]
# 	RMS: 0.1845866
# 	Segment Info:
# 	Suggest: [0.67, 0.33, 0.0, 0.0]
# 	RMS: 0.16980733
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.17682333
# Pred: Q1
# True: Q1
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.06340491
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.07051844
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.07440972
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.07784404
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.07576984
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.07693902
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.07565212
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.076053806
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.0783222
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.08195639
# 	Segment Info:
# 	Suggest: [0.6, 0.0, 0.4, 0.0]
# 	RMS: 0.08192057
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.085707575
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.08911901
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.08772296
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.09431933
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.0970323
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.10701969
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.10959603
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.11356278
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.11337007
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.11549874
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.1142623
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.1092038
# 	Segment Info:
# 	Suggest: [0.72, 0.0, 0.28, 0.0]
# 	RMS: 0.116063274
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.11033698
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.10747615
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.107178144
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.114435144
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.11005001
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.10683485
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.10011582
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.09180525
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.0936736
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.08896821
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.091042385
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.0929874
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.08739327
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.080227755
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.07740087
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.07754239
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.079380855
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.08127197
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.079259686
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.07504963
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.071069
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.06573907
# Pred: Q1
# True: Q1
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.19082567
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.21652433
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.2409626
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.04, 0.0, 0.0, 0.96]
# 	RMS: 0.25605884
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.25607976
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.07, 0.93]
# 	RMS: 0.25398776
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.21, 0.79]
# 	RMS: 0.2531469
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.25321314
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.02, 0.98]
# 	RMS: 0.25568375
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.25365514
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.24749385
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.23845814
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.03, 0.0, 0.1, 0.87]
# 	RMS: 0.22569071
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.2149695
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.21177544
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.21438986
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.26, 0.0, 0.0, 0.73]
# 	RMS: 0.21951808
# 	Segment Info:
# 	Suggest: [0.99, 0.0, 0.0, 0.01]
# 	RMS: 0.2289016
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.22, 0.0, 0.0, 0.78]
# 	RMS: 0.23031715
# 	Segment Info:
# 	Suggest: [0.77, 0.0, 0.0, 0.23]
# 	RMS: 0.23485106
# 	Segment Info:
# 	Suggest: [0.79, 0.0, 0.0, 0.21]
# 	RMS: 0.24114256
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.24746695
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.44, 0.0, 0.01, 0.55]
# 	RMS: 0.24878061
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.3, 0.0, 0.0, 0.7]
# 	RMS: 0.24864294
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.2559035
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.25924525
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.255508
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.25030586
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.01, 0.99]
# 	RMS: 0.24676114
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.51, 0.49]
# 	RMS: 0.23885119
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.2319497
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.02, 0.98]
# 	RMS: 0.2360339
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.89, 0.11]
# 	RMS: 0.24045344
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.24404967
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.24252908
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.24318586
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.03, 0.0, 0.37, 0.6]
# 	RMS: 0.2446167
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.24243906
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.24515949
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.25250256
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.25969234
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.25600702
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.2572
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.01, 0.0, 0.0, 0.99]
# 	RMS: 0.25453287
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.25472325
# 	Segment Info:
# 	Suggest: [0.69, 0.0, 0.0, 0.31]
# 	RMS: 0.25545457
# Pred: Q4
# True: Q1
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.01, 0.0, 0.0, 0.99]
# 	RMS: 0.15088566
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.16960786
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.18427993
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.12, 0.0, 0.88]
# 	RMS: 0.19012673
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.25, 0.0, 0.75]
# 	RMS: 0.19172506
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.06, 0.0, 0.94]
# 	RMS: 0.19279689
# 	Segment Info:
# 	Suggest: [0.89, 0.05, 0.0, 0.06]
# 	RMS: 0.19845083
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19970043
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19583787
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.03, 0.97, 0.0, 0.01]
# 	RMS: 0.19353029
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.21, 0.43, 0.0, 0.36]
# 	RMS: 0.1959522
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.42, 0.02, 0.0, 0.56]
# 	RMS: 0.19512971
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.05, 0.06, 0.0, 0.89]
# 	RMS: 0.19293912
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.01, 0.0, 0.99]
# 	RMS: 0.19179235
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.01, 0.72, 0.0, 0.27]
# 	RMS: 0.19097032
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.192008
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.1851599
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.18544967
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.1824855
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.17971285
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.01, 0.99]
# 	RMS: 0.18131429
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.26, 0.74]
# 	RMS: 0.17771953
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.64, 0.36]
# 	RMS: 0.1794432
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.93, 0.07]
# 	RMS: 0.17706878
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.05, 0.0, 0.86, 0.09]
# 	RMS: 0.18146665
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.18447907
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.5, 0.0, 0.36, 0.14]
# 	RMS: 0.1856911
# 	Segment Info:
# 	Suggest: [0.66, 0.0, 0.21, 0.13]
# 	RMS: 0.18020591
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.03, 0.97]
# 	RMS: 0.18173043
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.14, 0.86]
# 	RMS: 0.18684158
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.15, 0.85]
# 	RMS: 0.18689883
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.186362
# 	Segment Info:
# 	Suggest: [0.88, 0.0, 0.09, 0.03]
# 	RMS: 0.18504937
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19173318
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.01, 0.0, 0.0, 0.99]
# 	RMS: 0.19019872
# 	Segment Info:
# 	Suggest: [0.96, 0.0, 0.0, 0.04]
# 	RMS: 0.19126874
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.49, 0.0, 0.0, 0.5]
# 	RMS: 0.1894639
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19560477
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19305494
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.18921636
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.18664075
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.18755245
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.19278024
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.18722963
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.1896827
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.18230873
# Pred: Q4
# True: Q1
# 	Segment Info:
# 	Suggest: [0.8, 0.2, 0.0, 0.0]
# 	RMS: 0.102252305
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.11398433
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.05, 0.95, 0.0, 0.0]
# 	RMS: 0.12153004
# 	Segment Info:
# 	Suggest: [0.99, 0.01, 0.0, 0.0]
# 	RMS: 0.12460094
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.21, 0.79, 0.0, 0.0]
# 	RMS: 0.12702993
# 	Segment Info:
# 	Suggest: [0.66, 0.34, 0.0, 0.0]
# 	RMS: 0.1318477
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.13054407
# 	Segment Info:
# 	Suggest: [0.89, 0.11, 0.0, 0.0]
# 	RMS: 0.13285662
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.13383496
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.13061468
# 	Segment Info:
# 	Suggest: [0.87, 0.13, 0.0, 0.0]
# 	RMS: 0.1318668
# 	Segment Info:
# 	Suggest: [0.98, 0.02, 0.0, 0.0]
# 	RMS: 0.13268448
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.13005848
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.02, 0.98, 0.0, 0.0]
# 	RMS: 0.1332271
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.127781
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.12392514
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.12113252
# 	Segment Info:
# 	Suggest: [0.82, 0.16, 0.0, 0.02]
# 	RMS: 0.11663133
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.11759157
# 	Segment Info:
# 	Suggest: [0.95, 0.05, 0.0, 0.0]
# 	RMS: 0.12138682
# 	Segment Info:
# 	Suggest: [0.92, 0.08, 0.0, 0.0]
# 	RMS: 0.12229158
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.12144824
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 1.0, 0.0, 0.0]
# 	RMS: 0.12953472
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.1328442
# 	Segment Info:
# 	Suggest: [0.63, 0.0, 0.37, 0.01]
# 	RMS: 0.13990772
# 	Segment Info:
# 	Suggest: [0.95, 0.0, 0.05, 0.0]
# 	RMS: 0.14450502
# 	Segment Info:
# 	Suggest: [0.95, 0.0, 0.05, 0.0]
# 	RMS: 0.15393631
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.15628707
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.15277517
# 	Segment Info:
# 	Suggest: [0.99, 0.0, 0.01, 0.0]
# 	RMS: 0.1469491
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.14275809
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.14441809
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.14323612
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.13900688
# 	Segment Info:
# 	Suggest: [0.96, 0.04, 0.0, 0.0]
# ...
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.17541711
# Pred: Q1
# True: Q4
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.06209377
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.96, 0.04]
# 	RMS: 0.07962329
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.09364792
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.10724691
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.12306165
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.13442095
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.14041397
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.14066328
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.13779423
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.13455652
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.12798111
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.11024458
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.09341656
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.07754836
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.1, 0.9]
# 	RMS: 0.06794211
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.06486523
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.01, 0.99]
# 	RMS: 0.06414364
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.52, 0.48]
# 	RMS: 0.06593849
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.075109914
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.07922028
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.08245333
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.083139434
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.08519909
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.087670416
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.083925754
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.07706409
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.07196444
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.07358449
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.26, 0.74]
# 	RMS: 0.070331335
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.07175949
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.07323476
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.07629832
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.07750617
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.0810272
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.08549498
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.086523585
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.08760277
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.08306479
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.07956142
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.076638766
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.072412714
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.06893441
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.06808819
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.78, 0.22]
# 	RMS: 0.06794163
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.07357688
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.08036036
# Pred: Q3
# True: Q4
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.21, 0.0, 0.79, 0.0]
# 	RMS: 0.078754805
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.085968144
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.093918845
# Incorrect!
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.10227103
# 	Segment Info:
# 	Suggest: [0.17, 0.0, 0.0, 0.83]
# 	RMS: 0.10676746
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 0.99]
# 	RMS: 0.10399172
# Incorrect!
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.1002605
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.87, 0.0, 0.12, 0.01]
# 	RMS: 0.09706577
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.86, 0.0, 0.14, 0.0]
# 	RMS: 0.09335041
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.35, 0.0, 0.65, 0.0]
# 	RMS: 0.088897
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.99, 0.0, 0.01, 0.0]
# 	RMS: 0.08841729
# Incorrect!
# 	Segment Info:
# 	Suggest: [1.0, 0.0, 0.0, 0.0]
# 	RMS: 0.087589175
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.98, 0.0, 0.0, 0.02]
# 	RMS: 0.08505214
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.04, 0.0, 0.96, 0.0]
# 	RMS: 0.08028193
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.07636701
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.07270703
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.06877591
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.06715811
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.062445454
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.99, 0.01]
# 	RMS: 0.0662129
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.06394647
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.06482168
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.06372656
# 	Segment Info:
# 	Suggest: [0.01, 0.0, 0.0, 0.99]
# 	RMS: 0.064741954
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.067128554
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.69, 0.0, 0.0, 0.3]
# 	RMS: 0.07012822
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.07333254
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.97, 0.0, 0.03]
# 	RMS: 0.076502785
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.08479816
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.76, 0.0, 0.24]
# 	RMS: 0.08921829
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.94, 0.0, 0.06]
# 	RMS: 0.0969642
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.6, 0.0, 0.4]
# 	RMS: 0.099511355
# 	Segment Info:
# 	Suggest: [0.0, 0.12, 0.0, 0.88]
# 	RMS: 0.10561203
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.103462376
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.10113564
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.09781572
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.09414391
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.08891104
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.08337034
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.15, 0.0, 0.77, 0.08]
# 	RMS: 0.078761436
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.09, 0.0, 0.73, 0.18]
# 	RMS: 0.07415685
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.070142515
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.0649485
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.06650219
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.02, 0.0, 0.98, 0.0]
# 	RMS: 0.06456671
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.068872824
# Pred: Q3
# True: Q4
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.97, 0.03]
# 	RMS: 0.06941837
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.07633004
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.08586742
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.09468111
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 0.99]
# 	RMS: 0.1022216
# 	Segment Info:
# 	Suggest: [0.12, 0.0, 0.38, 0.51]
# 	RMS: 0.10251828
# 	Segment Info:
# 	Suggest: [0.07, 0.0, 0.27, 0.66]
# 	RMS: 0.1046565
# 	Segment Info:
# 	Suggest: [0.04, 0.0, 0.0, 0.96]
# 	RMS: 0.11071767
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.111400165
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.124983124
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.12243017
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.13055499
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.13304439
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.13456284
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.12975977
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.122257374
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.11541031
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.103448994
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.10662098
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.0926548
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.09721981
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.08842629
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.084922604
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.08474766
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.08931619
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.09360904
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.09478793
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.105408914
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.105416484
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.104637764
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.0932953
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.0890491
# 	Segment Info:
# 	Suggest: [0.0, 0.01, 0.0, 0.99]
# 	RMS: 0.08219208
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.89, 0.0, 0.1, 0.0]
# 	RMS: 0.07371726
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.99, 0.0, 0.01, 0.0]
# 	RMS: 0.0650834
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.01, 0.98]
# 	RMS: 0.0645158
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.060773905
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.055461273
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.01, 0.99]
# 	RMS: 0.050773453
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.052444555
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.060834613
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.12, 0.88]
# 	RMS: 0.06601682
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.068395466
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.07352128
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.07935109
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.07870772
# Pred: Q4
# True: Q4
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.083782755
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.09441448
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.10298462
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.11170145
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.11920756
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.12550141
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.1225296
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.11498919
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.10826133
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.103875436
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.95, 0.05]
# 	RMS: 0.10111925
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.10103548
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.99, 0.01]
# 	RMS: 0.10284554
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.10186261
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.10324632
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.10367393
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.98, 0.02]
# 	RMS: 0.10927515
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.99, 0.01]
# 	RMS: 0.10911285
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.32, 0.68]
# 	RMS: 0.111806765
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.11481334
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.11321369
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.10737222
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.10197525
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.09710611
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.090286866
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.08313894
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.080395326
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.08304454
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.08607901
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.08471376
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.088233046
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.09355663
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.09687537
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.09861531
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.10120829
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.1077886
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.10528941
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.102927715
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.09602451
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.095627435
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.093495384
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.09296832
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.09121722
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.092069976
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.089174256
# Incorrect!
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 1.0, 0.0]
# 	RMS: 0.086433284
# Pred: Q3
# True: Q4
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.085037455
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.09012351
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.09478534
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.09307033
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.09255816
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.09116805
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.090002485
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.088151686
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.083324954
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.081270106
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.079727896
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.08011228
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.07960612
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.079105996
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.08060579
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.07940153
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.08008618
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.0741438
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.06, 0.94]
# 	RMS: 0.07371428
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.081178084
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.09054384
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.09703031
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.105477236
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.11492192
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.123863555
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.13403837
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.13936004
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.15615974
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.16690971
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.16686916
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.1618587
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.16597809
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.15815271
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.14883874
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.13810287
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.13067354
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.13041073
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.12591074
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.12767345
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.12635355
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.13419522
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.13181221
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.13221514
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.1376482
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.14273694
# 	Segment Info:
# 	Suggest: [0.0, 0.0, 0.0, 1.0]
# 	RMS: 0.1431225
# Pred: Q4

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt


f_lab = "np.mean(chroma_stft), np.mean(rmse), np.mean(spec_cent), np.mean(spec_bw), np.mean(rolloff), np.mean(zcr)".split(",")
for i in range(20):
  f_lab.append("mfcc")
print(len(rmss[0]))
print(len(rmss[1]))
print(rmss[0][0].size())
for i in range(26):
  print("Feature:", f_lab[i])
  print("Faiure, Correct")
  plt.subplot(1,2,1)
  plt.hist([j.cpu()[0][i] for j in rmss[0]])
  plt.subplot(1,2,2)
  plt.hist([j.cpu()[0][i] for j in rmss[1]])
  plt.show()
# Out:
# 1849
# 2699
# torch.Size([1, 26])
# Feature: np.mean(chroma_stft)
# Faiure, Correct
# Feature:  np.mean(rmse)
# Faiure, Correct
# Feature:  np.mean(spec_cent)
# Faiure, Correct
# Feature:  np.mean(spec_bw)
# Faiure, Correct
# Feature:  np.mean(rolloff)
# Faiure, Correct
# Feature:  np.mean(zcr)
# Faiure, Correct
# Feature: mfcc
# Faiure, Correct
# Feature: mfcc
# Faiure, Correct
# Feature: mfcc
# Faiure, Correct
# Feature: mfcc
# Faiure, Correct
# Feature: mfcc
# Faiure, Correct
# Feature: mfcc
# Faiure, Correct
# Feature: mfcc
# Faiure, Correct
# Feature: mfcc
# Faiure, Correct
# Feature: mfcc
# Faiure, Correct
# Feature: mfcc
# Faiure, Correct
# Feature: mfcc
# Faiure, Correct
# Feature: mfcc
# Faiure, Correct
# Feature: mfcc
# Faiure, Correct
# Feature: mfcc
# Faiure, Correct
# Feature: mfcc
# Faiure, Correct
# Feature: mfcc
# Faiure, Correct
# Feature: mfcc
# Faiure, Correct
# Feature: mfcc
# Faiure, Correct
# Feature: mfcc
# Faiure, Correct
# Feature: mfcc
# Faiure, Correct

# %% [markdown]
# 1849

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2699

# %% [markdown]
# ![image.png](data:image/png;base64,...)
