# %%
from google.colab import drive
drive.mount('/content/drive')
RESEARCH_WORK_PATH = "/content/drive/My Drive/Colab Notebooks/BachelorResearch/"
# Out:
# Mounted at /content/drive

# %%
import math
import torch
from torch import nn

# %% [markdown]
# # Model

# %%
class Swish(nn.Module):
  def forward(self, x):
    return x * torch.sigmoid(x)

# %%
class FeatureEx1d(nn.Module):
  def __init__(self, input_size):
    super().__init__()
    self.layers = nn.Sequential(
        nn.linear(input_size, 256),
        nn.functional.relu(),
        nn.linear(256, 128),
        nn.functional.relu(),
        nn.linear(128, 64),
        nn.functional.relu()
    )

  def forward(self, x):
    return self.layers(x)

# %%
class SEblock(nn.Module):
  def __init__(self, ch_in, ch_sq):
    super().__init__()
    self.se = nn.Sequential(
        nn.AdaptiveAvgPool2d(1),
        nn.Conv2d(ch_in, ch_sq, 1),
        Swish(),
        nn.Conv2d(ch_sq, ch_in, 1),
    )
    self.se.apply(weight_init)

  def forward(self, x):
    return x * torch.sigmoid(self.se(x))

def weight_init(m):
  if isinstance(m, nn.Conv2d):
    nn.init.kaiming_normal_(m.weight)

  if isinstance(m, nn.Linear):
    nn.init.kaiming_uniform_(m.weight)
    nn.init.zeros_(m.bias)

# %%
class ConvBN(nn.Module):
  def __init__(self, ch_in, ch_out, kernel_size, stride=1, padding=0, groups=1):
    super().__init__()
    self.layers=nn.Sequential(
        nn.Conv2d(ch_in, ch_out, kernel_size, stride, padding, groups=groups, bias=False),
        nn.BatchNorm2d(ch_out),
    )
    self.layers.apply(weight_init)

  def forward(self, x):
    return self.layers(x)

# %%
class DropConnect(nn.Module):
  def __init__(self, drop_rate):
    super().__init__()
    self.drop_rate=drop_rate

  def forward(self, x):
    if self.training:
      keep_rate=1.0-self.drop_rate
      r = torch.rand([x.size(0),1,1,1], dtype=x.dtype).to(x.device)
      r+=keep_rate
      mask=r.floor()
      return x.div(keep_rate)*mask
    else:
      return x

# %%
class BMConvBlock(nn.Module):
  def __init__(self,ch_in,ch_out,expand_ratio,stride,kernel_size,reduction_ratio=4,drop_connect_rate=0.2):
    super().__init__()
    self.use_residual = (ch_in==ch_out) & (stride==1)
    ch_med = int(ch_in*expand_ratio)
    ch_sq  = max(1, ch_in//reduction_ratio)

    if expand_ratio != 1.0:
      layers = [ConvBN(ch_in, ch_med, 1), Swish()]
    else:
      layers = []
    
    layers.extend([ConvBN(ch_med, ch_med, kernel_size, stride=stride, padding=(kernel_size)//2, groups=ch_med),
                  Swish(),
                  SEblock(ch_med, ch_sq),
                  ConvBN(ch_med, ch_out, 1),
                  ])
    
    if self.use_residual:
      self.drop_connect = DropConnect(drop_connect_rate)

    self.layers = nn.Sequential(*layers)

  def forward(self, x):
    if self.use_residual:
      return x + self.drop_connect(self.layers(x))
    else:
      return self.layers(x)

# %%
class Flatten(nn.Module):
  def forward(self, x):
    return x.view(x.shape[0], -1)

# %%
class MultiModalNet(nn.Module):
  def __init__(self,
               width_mult=1.0,
               depth_mult=1.0,
               resolution=None,
               dropout_rate=0.2,
               num_1d_features=10,
               num_classes=4,
               input_ch=3):
    super().__init__()

    # expand_ratio, channel, repeats, stride, kernel_size                   
    settings = [
        [1,  16, 1, 1, 3],  # MBConv1_3x3, SE, 112 -> 112                   
        [6,  24, 2, 2, 3],  # MBConv6_3x3, SE, 112 ->  56                   
        [6,  40, 2, 2, 5],  # MBConv6_5x5, SE,  56 ->  28                   
        [6,  80, 3, 2, 3],  # MBConv6_3x3, SE,  28 ->  14                   
        [6, 112, 3, 1, 5],  # MBConv6_5x5, SE,  14 ->  14                   
        [6, 192, 4, 2, 5],  # MBConv6_5x5, SE,  14 ->   7                   
        [6, 320, 1, 1, 3]   # MBConv6_3x3, SE,   7 ->   7]                  
    ]
    ch_out = int(math.ceil(32*width_mult))
    features = [nn.AdaptiveAvgPool2d(resolution)] if resolution else []
    features.extend([ConvBN(input_ch, ch_out, 3, stride=2), Swish()])     # -> [32, 3, 3, 3]

    ch_in = ch_out
    for t, c, n, s, k in settings:
      ch_out = int(math.ceil(c*width_mult))
      repeats = int(math.ceil(n*depth_mult))
      for i in range(repeats):
        stride = s if i==0 else 1
        features.extend([BMConvBlock(ch_in, ch_out, t, stride, k)])
        ch_in = ch_out

    ch_last = int(math.ceil(1280*width_mult))
    features.extend([ConvBN(ch_in, ch_last, 1), Swish()])

    self.features2d = nn.Sequential(*features)
    self.reshape = nn.Sequential(
        nn.AdaptiveAvgPool2d(1),
        Flatten(),
        nn.Dropout(dropout_rate),
        nn.Linear(ch_last, 128)
    )
    self.classifier = nn.Sequential(
        nn.Linear(128*2, 128),
        nn.ReLU(),
        nn.Linear(128, 64),
        nn.ReLU(),
        nn.Linear(64, num_classes),
        nn.Softmax(dim=1)
    )

    self.features1d = nn.Sequential(
        nn.Linear(num_1d_features, 256),
        nn.ReLU(),
        nn.Linear(256, 128),
        nn.ReLU(),
    )

  def forward(self, x):
    x1=self.features2d(x[1])
    x1=self.reshape(x1)
    x0=self.features1d(x[0])
    x = torch.cat((x0,x1), dim=1)
    x=self.classifier(x)

    return x

# %% [markdown]
# # Model (Instance)

# %%
from torch import optim

num_1d_features = 26
model     = MultiModalNet(input_ch=1, num_classes=4, num_1d_features=num_1d_features).to('cuda')
optimizer = optim.SGD(model.parameters(),lr=0.05)
criterion = nn.CrossEntropyLoss()

# %%
import soundfile as sf
import librosa
import pathlib
import numpy as np
from matplotlib import pyplot as plt
from tensorflow import keras 
import os
import cv2
import pickle
import torch

model_path = '/content/drive/MyDrive/Colab Notebooks/BachelorResearch/models/multimodal_5s_0.5shift.pth'
model.load_state_dict(torch.load(model_path))
scaler = pickle.load(open(RESEARCH_WORK_PATH + "/models/1d_scaler_5s_0.5shift.pickle", "rb"))
# Out:
# MultiModalNet(
#   (features2d): Sequential(
#     (0): ConvBN(
#       (layers): Sequential(
#         (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Swish()
#     (2): BMConvBlock(
#       (layers): Sequential(
#         (0): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Swish()
#         (2): SEblock(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (3): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (3): BMConvBlock(
#       (layers): Sequential(
#         (0): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Swish()
#         (2): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (3): Swish()
#         (4): SEblock(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (5): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (4): BMConvBlock(
#       (drop_connect): DropConnect()
#       (layers): Sequential(
#         (0): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Swish()
#         (2): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (3): Swish()
#         (4): SEblock(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (5): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (5): BMConvBlock(
#       (layers): Sequential(
#         (0): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Swish()
#         (2): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (3): Swish()
#         (4): SEblock(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (5): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (6): BMConvBlock(
#       (drop_connect): DropConnect()
#       (layers): Sequential(
#         (0): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Swish()
#         (2): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (3): Swish()
#         (4): SEblock(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (5): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (7): BMConvBlock(
#       (layers): Sequential(
#         (0): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Swish()
#         (2): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (3): Swish()
#         (4): SEblock(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (5): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (8): BMConvBlock(
#       (drop_connect): DropConnect()
#       (layers): Sequential(
#         (0): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Swish()
#         (2): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (3): Swish()
#         (4): SEblock(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (5): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (9): BMConvBlock(
#       (drop_connect): DropConnect()
#       (layers): Sequential(
#         (0): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Swish()
#         (2): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (3): Swish()
#         (4): SEblock(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (5): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (10): BMConvBlock(
#       (layers): Sequential(
#         (0): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Swish()
#         (2): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (3): Swish()
#         (4): SEblock(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (5): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (11): BMConvBlock(
#       (drop_connect): DropConnect()
#       (layers): Sequential(
#         (0): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Swish()
#         (2): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (3): Swish()
#         (4): SEblock(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (5): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (12): BMConvBlock(
#       (drop_connect): DropConnect()
#       (layers): Sequential(
#         (0): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Swish()
#         (2): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (3): Swish()
#         (4): SEblock(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (5): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (13): BMConvBlock(
#       (layers): Sequential(
#         (0): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Swish()
#         (2): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (3): Swish()
#         (4): SEblock(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (5): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (14): BMConvBlock(
#       (drop_connect): DropConnect()
#       (layers): Sequential(
#         (0): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Swish()
#         (2): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (3): Swish()
#         (4): SEblock(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (5): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (15): BMConvBlock(
#       (drop_connect): DropConnect()
#       (layers): Sequential(
#         (0): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Swish()
#         (2): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (3): Swish()
#         (4): SEblock(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (5): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (16): BMConvBlock(
#       (drop_connect): DropConnect()
#       (layers): Sequential(
#         (0): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Swish()
#         (2): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (3): Swish()
#         (4): SEblock(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (5): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (17): BMConvBlock(
#       (layers): Sequential(
#         (0): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Swish()
#         (2): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (3): Swish()
#         (4): SEblock(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (5): ConvBN(
#           (layers): Sequential(
#             (0): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (18): ConvBN(
#       (layers): Sequential(
#         (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (19): Swish()
#   )
#   (reshape): Sequential(
#     (0): AdaptiveAvgPool2d(output_size=1)
#     (1): Flatten()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=1280, out_features=128, bias=True)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=256, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=4, bias=True)
#     (5): Softmax(dim=1)
#   )
#   (features1d): Sequential(
#     (0): Linear(in_features=26, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=128, bias=True)
#     (3): ReLU()
#   )
# )

# %% [markdown]
# # Visualization

# %%
from matplotlib import pyplot as plt
print(model.state_dict().keys())


layer_bias = np.array(model.state_dict()['features2d.0.layers.1.bias'].to('cpu'))
print(layer_bias.shape)
print(layer_bias)

plt.figure(figsize=(16,16))
for i in range(16):
  kernel_weight = np.array(model.state_dict()['features2d.0.layers.0.weight'].to('cpu'))[i].reshape(3,3)


  plt.subplot(4, 4, i+1)
  plt.title(f"kernel_weight : {i+1}")
  plt.imshow(kernel_weight, cmap="gray")

 
plt.show()
# Out:
# odict_keys(['features2d.0.layers.0.weight', 'features2d.0.layers.1.weight', 'features2d.0.layers.1.bias', 'features2d.0.layers.1.running_mean', 'features2d.0.layers.1.running_var', 'features2d.0.layers.1.num_batches_tracked', 'features2d.2.layers.0.layers.0.weight', 'features2d.2.layers.0.layers.1.weight', 'features2d.2.layers.0.layers.1.bias', 'features2d.2.layers.0.layers.1.running_mean', 'features2d.2.layers.0.layers.1.running_var', 'features2d.2.layers.0.layers.1.num_batches_tracked', 'features2d.2.layers.2.se.1.weight', 'features2d.2.layers.2.se.1.bias', 'features2d.2.layers.2.se.3.weight', 'features2d.2.layers.2.se.3.bias', 'features2d.2.layers.3.layers.0.weight', 'features2d.2.layers.3.layers.1.weight', 'features2d.2.layers.3.layers.1.bias', 'features2d.2.layers.3.layers.1.running_mean', 'features2d.2.layers.3.layers.1.running_var', 'features2d.2.layers.3.layers.1.num_batches_tracked', 'features2d.3.layers.0.layers.0.weight', 'features2d.3.layers.0.layers.1.weight', 'features2d.3.layers.0.layers.1.bias', 'features2d.3.layers.0.layers.1.running_mean', 'features2d.3.layers.0.layers.1.running_var', 'features2d.3.layers.0.layers.1.num_batches_tracked', 'features2d.3.layers.2.layers.0.weight', 'features2d.3.layers.2.layers.1.weight', 'features2d.3.layers.2.layers.1.bias', 'features2d.3.layers.2.layers.1.running_mean', 'features2d.3.layers.2.layers.1.running_var', 'features2d.3.layers.2.layers.1.num_batches_tracked', 'features2d.3.layers.4.se.1.weight', 'features2d.3.layers.4.se.1.bias', 'features2d.3.layers.4.se.3.weight', 'features2d.3.layers.4.se.3.bias', 'features2d.3.layers.5.layers.0.weight', 'features2d.3.layers.5.layers.1.weight', 'features2d.3.layers.5.layers.1.bias', 'features2d.3.layers.5.layers.1.running_mean', 'features2d.3.layers.5.layers.1.running_var', 'features2d.3.layers.5.layers.1.num_batches_tracked', 'features2d.4.layers.0.layers.0.weight', 'features2d.4.layers.0.layers.1.weight', 'features2d.4.layers.0.layers.1.bias', 'features2d.4.layers.0.layers.1.running_mean', 'features2d.4.layers.0.layers.1.running_var', 'features2d.4.layers.0.layers.1.num_batches_tracked', 'features2d.4.layers.2.layers.0.weight', 'features2d.4.layers.2.layers.1.weight', 'features2d.4.layers.2.layers.1.bias', 'features2d.4.layers.2.layers.1.running_mean', 'features2d.4.layers.2.layers.1.running_var', 'features2d.4.layers.2.layers.1.num_batches_tracked', 'features2d.4.layers.4.se.1.weight', 'features2d.4.layers.4.se.1.bias', 'features2d.4.layers.4.se.3.weight', 'features2d.4.layers.4.se.3.bias', 'features2d.4.layers.5.layers.0.weight', 'features2d.4.layers.5.layers.1.weight', 'features2d.4.layers.5.layers.1.bias', 'features2d.4.layers.5.layers.1.running_mean', 'features2d.4.layers.5.layers.1.running_var', 'features2d.4.layers.5.layers.1.num_batches_tracked', 'features2d.5.layers.0.layers.0.weight', 'features2d.5.layers.0.layers.1.weight', 'features2d.5.layers.0.layers.1.bias', 'features2d.5.layers.0.layers.1.running_mean', 'features2d.5.layers.0.layers.1.running_var', 'features2d.5.layers.0.layers.1.num_batches_tracked', 'features2d.5.layers.2.layers.0.weight', 'features2d.5.layers.2.layers.1.weight', 'features2d.5.layers.2.layers.1.bias', 'features2d.5.layers.2.layers.1.running_mean', 'features2d.5.layers.2.layers.1.running_var', 'features2d.5.layers.2.layers.1.num_batches_tracked', 'features2d.5.layers.4.se.1.weight', 'features2d.5.layers.4.se.1.bias', 'features2d.5.layers.4.se.3.weight', 'features2d.5.layers.4.se.3.bias', 'features2d.5.layers.5.layers.0.weight', 'features2d.5.layers.5.layers.1.weight', 'features2d.5.layers.5.layers.1.bias', 'features2d.5.layers.5.layers.1.running_mean', 'features2d.5.layers.5.layers.1.running_var', 'features2d.5.layers.5.layers.1.num_batches_tracked', 'features2d.6.layers.0.layers.0.weight', 'features2d.6.layers.0.layers.1.weight', 'features2d.6.layers.0.layers.1.bias', 'features2d.6.layers.0.layers.1.running_mean', 'features2d.6.layers.0.layers.1.running_var', 'features2d.6.layers.0.layers.1.num_ ...
# (32,)
# [-0.07087987 -0.02790865  0.09691469  0.02790591 -0.02004129  0.03913327
#   0.16868603 -0.06113645 -0.0151998   0.0031504  -0.01224058  0.03244545
#   0.04170118 -0.02263505 -0.00555892  0.03206372 -0.02104909 -0.00952948
#   0.09437265  0.06659354  0.03489088 -0.04116645  0.01335075  0.01988936
#   0.06782022  0.05177564  0.19113381 -0.00321056  0.0448617   0.00673311
#   0.05832085 -0.03549705]

# %%
pickle_path = "/content/drive/MyDrive/BachelorResearch/MER_audio_taffc_dataset_wav/5s_0.5shift/pickles1/Q1/Q1.MT0000040632_18.wav.pickle"
x,y = pickle.load(open(pickle_path, mode="rb"))

x1=model.features2d(x[1])
x1=model.reshape(x1)
x0=model.features1d(x[0])
x = torch.cat((x0,x1), dim=1)
x=model.classifier(x)
