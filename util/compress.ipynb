# %%
import shutil
import pathlib
import os
dir = pathlib.Path("/content/drive/MyDrive/Colab Notebooks/BachelorResearch/MER_audio_taffc_dataset_wav/2s/stft_crop_0.1")
os.chdir(dir.parent)
shutil.make_archive(dir.name, format='zip', root_dir=dir.name)
# Out:
# '/content/drive/MyDrive/Colab Notebooks/BachelorResearch/MER_audio_taffc_dataset_wav/2s/stft_crop_0.1.zip'
